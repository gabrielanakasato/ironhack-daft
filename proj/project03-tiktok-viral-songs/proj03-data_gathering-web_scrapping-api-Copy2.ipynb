# %% [markdown]
# ![Ironhack logo](https://i.imgur.com/1QgrNNw.png)

# %% [markdown]
# <body>
#     <p style="font-size:28px;text-align:center"><b>Project 03 - Part 01 | Web Scrapping & API</b></p>
# </body>

# %% [markdown]
# # Introduction

# %% [markdown]
# The objective of the first part of this project was collect data to answer a problem statement, practicing web scrapping and using API.
#
# ---
#
# <body>
#     <p style="font-size:20px"><b>Problem Statement</b></p>
# </body>
#
# _What some the TikTok viral songs have in common?_
#
# ---
#
# To answer this problem, 69 songs, which were obtained from the **PopSugar** website, were analyzed. The post that contained this list of songs was made in March 27th, 2020 by Hedy Phillips around the same time people started to quarantine, because of the COVIVD-19 pandemic, and people began to use it more to spend their time at home.
#
# The sources of information used to gather data were **Spotify**,  **Last.fm**, **Chartmetric** and **MusicBrainz**.
#
# ---
#
# Sources:
# - Websites:
#   - PopSugar: https://www.popsugar.com/entertainment/popular-tiktok-songs-47289804?stream_view=1#photo-47289832
#   - MusicBrainz:https://musicbrainz.org/genres
#
# - APIs
#   - Spotify API: https://developer.spotify.com/
#   - Spotipy (Spotify API wrapper for Python): https://spotipy.readthedocs.io/en/2.15.0/
#   - Last.fm API: https://www.last.fm/api
#   - Chartmetric API: https://api.chartmetric.com/apidoc/

# %% [markdown]
# # Setup

# %% [markdown]
# ## Import

# %%
import os
import re
import requests

from ast import literal_eval
from time import sleep

import numpy as np
import pandas as pd
import spotipy

from bs4 import BeautifulSoup
from dotenv import load_dotenv, find_dotenv
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
from tqdm.auto import tqdm

# %% [markdown]
# # Web Scrapping

# %% [markdown]
# The web scrapping was necessary to collect the following data:
#
# <table>
#   <thead>
#     <tr>
#       <th>INFORMATION</th>
#       <th>SOURCE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>69 TikTok viral songs</td>
#       <td>PopSugar</td>
#     </tr>
#     <tr>
#       <td>Music genres</td>
#       <td>MusicBrainz</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## List of viral songs on TikTok

# %% [markdown]
# ### Get response

# %%
# Get response from the url and check it
url = 'https://www.popsugar.com/entertainment/popular-tiktok-songs-47289804?stream_view=1#photo-47289832'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Data Collection

# %%
# Get the content in the url
content_popsugar = BeautifulSoup(response.text)

# Get the date the post was made
popsugar_date = content_popsugar.find('time').text.replace('\n', '').strip()

# Get only the songs and artists
popsugar_html = content_popsugar.find_all('span', attrs={'class': 'count-copy'})

# %%
# Conver the list 'html_popsugar' to a Pandas DataFrame
df_base = pd.DataFrame([re.split(' by ', song.text.replace('"', '').strip()) for song in popsugar_html], 
                       columns=['song', 'artists'])

# Check the result
df_base
# Out:
#                 song                                         artists
# 0            Roxanne                                  Arizona Zervas
# 1             Say So                                        Doja Cat
# 2           My Oh My                     Camila Cabello feat. DaBaby
# 3               Moon                                 Kid Francescoli
# 4               Vibe                                  Cookiee Kawaii
# ..               ...                                             ...
# 64     What the Hell                                   Avril Lavigne
# 65   Towards the Sun                                         Rihanna
# 66  I Think I'm OKAY  Machine Gun Kelly, YUNGBLUD, and Travis Barker
# 67            Myself                                           Bazzi
# 68          Stronger                                      Kanye West
#
# [69 rows x 2 columns]

# %% [markdown]
# ### Data Cleaning

# %%
# Create a column with a list of artists for each song
df_base['artists_list'] = [re.split(',* and |, * | [Ff]eat. ', artists.strip()) for artists in df_base.artists]

# Create a column with the number of artists for each song
df_base['number_artists'] = df_base.artists_list.apply(len)

# %%
# Check possible number of artists for one song
df_base.number_artists.value_counts()
# Out:
# 1    48
# 2    18
# 3     3
# Name: number_artists, dtype: int64

# %% [markdown]
# Seeing the result above, the maximum number of artists for a song is 3.

# %%
# Check the dataframe
df_base.head()
# Out:
#        song                      artists              artists_list  \
# 0   Roxanne               Arizona Zervas          [Arizona Zervas]
# 1    Say So                     Doja Cat                [Doja Cat]
# 2  My Oh My  Camila Cabello feat. DaBaby  [Camila Cabello, DaBaby]
# 3      Moon              Kid Francescoli         [Kid Francescoli]
# 4      Vibe               Cookiee Kawaii          [Cookiee Kawaii]
#
#    number_artists
# 0               1
# 1               1
# 2               2
# 3               1
# 4               1

# %% [markdown]
# ### Make backup dataframe

# %%
df_base_raw_bck = df_base.copy()

# %% [markdown]
# ## List of music genre

# %% [markdown]
# ### Get the response

# %%
'''# Get response from the url and check it
url = 'https://musicbrainz.org/genres'
response = requests.get(url)
response'''
# Out:
# "# Get response from the url and check it\nurl = 'https://musicbrainz.org/genres'\nresponse = requests.get(url)\nresponse"

# %% [markdown]
# ### Data collection

# %%
'''# Get the content in the url
musicbrainz_content = BeautifulSoup(response.content)

# Create a list with the music genres listed in the url
musicbrainz_genre = [genre.text for genre in musicbrainz_content.find_all('bdi')]'''
# Out:
# "# Get the content in the url\nmusicbrainz_content = BeautifulSoup(response.content)\n\n# Create a list with the music genres listed in the url\nmusicbrainz_genre = [genre.text for genre in musicbrainz_content.find_all('bdi')]"

# %% [markdown]
# The data cleaning for this list will be made later.

# %% [markdown]
# # Spotify

# %% [markdown]
# From the Spotify and with the Spotipy's help, some data about each song will be gathered. It is relevant to point that there is a possibility that some songs may not be in the Spotify's library.

# %%
# Create a copy of the dataframe
df_sp = df_base.copy()

# Check the result
df_sp.head()
# Out:
#        song                      artists              artists_list  \
# 0   Roxanne               Arizona Zervas          [Arizona Zervas]
# 1    Say So                     Doja Cat                [Doja Cat]
# 2  My Oh My  Camila Cabello feat. DaBaby  [Camila Cabello, DaBaby]
# 3      Moon              Kid Francescoli         [Kid Francescoli]
# 4      Vibe               Cookiee Kawaii          [Cookiee Kawaii]
#
#    number_artists
# 0               1
# 1               1
# 2               2
# 3               1
# 4               1

# %% [markdown]
# ## Connecting to the API

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
cid = os.getenv('spotify_p03_key')
csecret = os.getenv('spotify_p03_secret')
cc_manager = SpotifyClientCredentials(client_id=cid, client_secret=csecret)
sp = spotipy.Spotify(client_credentials_manager=cc_manager)

# %% [markdown]
# ## Songs

# %% [markdown]
# ### Search information about each song

# %%
# Search information about each song, using the Spotipy
spotify_songs = [sp.search(q=df_base.iloc[index, 0], type='track', limit=50) for index in tqdm(df_base.index)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=69.0), HTML(value='')))

# %%
# Check if there are 69 items in this list
len(spotify_songs)
# Out:
# 69

# %%
# Add a column in the dataframe with the data that were just collected
df_sp['spotify_search'] = spotify_songs

# %%
# Check the result
df_sp.head()
# Out:
#        song                      artists              artists_list  \
# 0   Roxanne               Arizona Zervas          [Arizona Zervas]
# 1    Say So                     Doja Cat                [Doja Cat]
# 2  My Oh My  Camila Cabello feat. DaBaby  [Camila Cabello, DaBaby]
# 3      Moon              Kid Francescoli         [Kid Francescoli]
# 4      Vibe               Cookiee Kawaii          [Cookiee Kawaii]
#
#    number_artists                                     spotify_search
# 0               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 1               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 2               2  {'tracks': {'href': 'https://api.spotify.com/v...
# 3               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 4               1  {'tracks': {'href': 'https://api.spotify.com/v...

# %%
# Function to add new information in a copy of the dataframe
def get_spotify_track_info(df):
    
    '''
    Filters some data of the songs and adds them to a copy of the dataframe
    
    Args:
    -----
        df (Pandas DataFrame): a dataframe containing the songs and their artists
    
    Returns:
    --------
        df_copy (Pandas DataFrame): a copy of the dataframe with some new information appended
    '''
    
    # Create auxiliary empty lists (final lists)
    list_spotify_track_id = []
    list_spotify_track_duration = []
    list_spotify_track_popularity = []
    list_spotify_album_release_date = []
    list_spotify_track_explicit = []
    lists_spotify = [list_spotify_track_id, list_spotify_track_duration, list_spotify_track_popularity,
                     list_spotify_album_release_date, list_spotify_track_explicit]
    
    
    # Check for each row of the dataframe
    for index in df.index:
        
        # Information necessary from the dataframe to use during the process
        song_name = df.iloc[index, 0][:3].lower()
        artists_list = [artist.lower() for artist in df.iloc[index, 2]]
        total_artists = df.iloc[index, 3]
        mask = df.iloc[index, 4]['tracks']['items']
        
        # If the track was not found in the Spotify library, a 'not-found' string is added to the final lists
        if len(mask) == 0:
            for lst in lists_spotify:
                lst.append('not-found')
            #print(f'{index} - {song_name} - NOT FOUND')
        
        # If the track was found in the Spotify
        else:
            
            # Variable necessary to check if the information about a song has been added to the final lists
            added = 0
            
            # For each track it was listed 50 tracks related to the query 
            for idx, each_found in enumerate(mask):
                
                # Information necessary from the Spotify API to use during the process
                track_name = mask[idx]['name'].lower()
                track_id = mask[idx]['id']
                track_duration = mask[idx]['duration_ms']
                track_popularity = mask[idx]['popularity']
                album_release_date = mask[idx]['album']['release_date']
                track_explicit = mask[idx]['explicit']
                n_artists = len(mask[idx]['artists'])
                first_artist_name = mask[idx]['artists'][0]['name'].lower()
            
                # Check if the name of the song, the artists from both sources match and if an information about the
                # song has been added to the final lists 
                if ((song_name in track_name) & (total_artists == n_artists) & 
                    ((first_artist_name in artists_list) | (artists_list[0][:5] in first_artist_name)) & (added == 0)):
                    list_spotify_track_id.append(track_id)
                    list_spotify_track_duration.append(track_duration)
                    list_spotify_track_popularity.append(track_popularity)
                    list_spotify_album_release_date.append(album_release_date)
                    list_spotify_track_explicit.append(track_explicit)
                    added += 1
                    #print(f'{index} - {track_name} - {track_id}')
                        
                
                # If the track found in the search is not a math, itis the last one and information about the track 
                # has not been added to the final list, then add a 'not-found' string to the final lists
                elif (idx == len(mask) - 1) & (added == 0):
                    for lst in lists_spotify:
                        lst.append('not-found')
                    #print(f'{index} - {song_name} - NOT FOUND')
    
    # Make a copy of the dataframe
    df_copy = df.copy()
    
    # Add columns with the desired information
    # Not an inplace process
    df_copy['sp_id'] = list_spotify_track_id
    df_copy['sp_duration_ms'] = list_spotify_track_duration
    df_copy['sp_popularity'] = list_spotify_track_popularity
    df_copy['sp_release_date'] = list_spotify_album_release_date
    df_copy['sp_explicit'] = list_spotify_track_explicit
                    
    return df_copy

# %%
# Add desired information to the dataframe
df_sp = get_spotify_track_info(df_sp)

# Check the result
df_sp
# Out:
#                 song                                         artists  \
# 0            Roxanne                                  Arizona Zervas
# 1             Say So                                        Doja Cat
# 2           My Oh My                     Camila Cabello feat. DaBaby
# 3               Moon                                 Kid Francescoli
# 4               Vibe                                  Cookiee Kawaii
# ..               ...                                             ...
# 64     What the Hell                                   Avril Lavigne
# 65   Towards the Sun                                         Rihanna
# 66  I Think I'm OKAY  Machine Gun Kelly, YUNGBLUD, and Travis Barker
# 67            Myself                                           Bazzi
# 68          Stronger                                      Kanye West
#
#                                     artists_list  number_artists  \
# 0                               [Arizona Zervas]               1
# 1                                     [Doja Cat]               1
# 2                       [Camila Cabello, DaBaby]               2
# 3                              [Kid Francescoli]               1
# 4                               [Cookiee Kawaii]               1
# ..                                           ...             ...
# 64                               [Avril Lavigne]               1
# 65                                     [Rihanna]               1
# 66  [Machine Gun Kelly, YUNGBLUD, Travis Barker]               3
# 67                                       [Bazzi]               1
# 68                                  [Kanye West]               1
#
#                                        spotify_search                   sp_id  \
# 0   {'tracks': {'href': 'https://api.spotify.com/v...  696DnlkuDOXcMAnKlTgXXK
# 1   {'tracks': {'href': 'https://api.spotify.com/v...  3Dv1eDb0MEgF93GpLXlucZ
# 2   {'tracks': {'href': 'https://api.spotify.com/v...  3yOlyBJuViE2YSGn3nVE1K
# 3   {'tracks': {'href': 'https://api.spotify.com/v...  24upABZ8A0sAepfu91sEYr
# 4   {'tracks': {'href': 'https://api.spotify.com/v...  4gOgQTv9RYYFZ1uQNnlk3q
# ..                                                ...                     ...
# 64  {'tracks': {'href': 'https://api.spotify.com/v...  2z4U9d5OAA4YLNXoCgioxo
# 65  {'tracks': {'href': 'https://api.spotify.com/v...  1UuZhGTon3gzXQAJzNa2A4
# 66  {'tracks': {'href': 'https://api.spotify.com/v...  2gTdDMpNxIRFSiu7HutMCg
# 67  {'tracks': {'href': 'https://api.spotify.com/v...  5YLHLxoZsodDWjqSgjhBf3
# 68  {'tracks': {'href': 'https://api.spotify.com/v...  4fzsfWzRhPawzqhX8Qt9F3
#
#    sp_duration_ms sp_popularity sp_release_date sp_explicit
# 0          163636            88      2019-10-10        True
# 1          237893            88      2019-11-07        True
# 2          170746            82      2019-12-06       False
# 3          390638            70      2017-03-03       False
# 4           83940            72      2019-03-29        True
# ..            ...           ...             ...         ...
# 64         220706            74      2011-03-08       False
# 65         273293            55      2015-03-23       False
# 66         169397            81      2019-07-05        True
# 67         167552            76      2018-04-12       False
# 68         311866            80      2007-09-11        True
#
# [69 rows x 10 columns]

# %%
# Check if songs were not found in Spotify
df_sp[df_sp.sp_id == 'not-found']
# Out:
#                            song                 artists          artists_list  \
# 11                How About Now           Bryson Tiller       [Bryson Tiller]
# 36  Shibuya — Chanel Funk Remix   Frank Ocean and L.Dre  [Frank Ocean, L.Dre]
# 39                          WOP  J. Dash feat. Flo Rida   [J. Dash, Flo Rida]
#
#     number_artists                                     spotify_search  \
# 11               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 36               2  {'tracks': {'href': 'https://api.spotify.com/v...
# 39               2  {'tracks': {'href': 'https://api.spotify.com/v...
#
#         sp_id sp_duration_ms sp_popularity sp_release_date sp_explicit
# 11  not-found      not-found     not-found       not-found   not-found
# 36  not-found      not-found     not-found       not-found   not-found
# 39  not-found      not-found     not-found       not-found   not-found

# %% [markdown]
# 3 songs were not found in Spotify. There were checked manually using the Spotify Desktop. The first two do not exist there. Finally, the third song exists, but the version with the featured artist in the dataframe does not exist there.

# %% [markdown]
# ### Find the audio features for each song

# %%
# Search in the API wrapper
spotify_audio_features = [sp.audio_features(track_id)  if track_id != 'not-found'else 'not-found' 
                          for track_id in tqdm(df_sp.sp_id)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=69.0), HTML(value='')))

# %%
# Check if there are 69 items in this list
len(spotify_audio_features)
# Out:
# 69

# %%
# Function to add new information in a copy of the dataframe
def get_spotify_audio_features(df, audio_features: list):
    
    '''
    Adds new information from a list to a copy of the dataframe
    
    Args:
    -----
        df (Pandas DataFrame): a dataframe containing the songs and their artists
    
    Returns:
    --------
        df_copy (Pandas DataFrame): a copy of the dataframe with some new information appended
    '''
    
    # Create auxiliary empty lists (final lists)
    list_danceability = []
    list_energy = []
    list_key = []
    list_loudness = []
    list_mode = []
    list_speechiness = []
    list_acousticness = []
    list_instrumentalness = []
    list_liveness = []
    list_valence = []
    list_tempo = []
    list_time_signature = []
    lists_features = [list_danceability, list_energy, list_key, list_loudness, list_mode, list_speechiness, 
                      list_acousticness, list_instrumentalness, list_liveness, list_valence, list_tempo,
                      list_time_signature]
    
    # Check for each row of the dataframe
    for index in df.index:
        
        # Get the track's Spotify id
        track_id = df.iloc[index, 5]
        
        # If the track was not found in the Spotify library, a 'not-found' string is added to the final lists
        if track_id == 'not-found':
            
            for lst in lists_features:
                lst.append('not-found')
    
        # If the track was found in the Spotify library
        else:
            
            # Add the information to the final lists
            list_danceability.append(audio_features[index][0]['danceability'])
            list_energy.append(audio_features[index][0]['energy'])
            list_key.append(audio_features[index][0]['key'])
            list_loudness.append(audio_features[index][0]['loudness'])
            list_mode.append(audio_features[index][0]['mode'])
            list_speechiness.append(audio_features[index][0]['speechiness'])
            list_acousticness.append(audio_features[index][0]['acousticness'])
            list_instrumentalness.append(audio_features[index][0]['instrumentalness'])
            list_liveness.append(audio_features[index][0]['liveness'])
            list_valence.append(audio_features[index][0]['valence'])
            list_tempo.append(audio_features[index][0]['tempo'])
            list_time_signature.append(audio_features[index][0]['time_signature'])
     
     # Make a copy of the dataframe
    df_copy = df.copy()
    
    # Add columns with the desired information
    # Not an inplace process
    df_copy['sp_danceability'] = list_danceability
    df_copy['sp_energy'] = list_energy
    df_copy['sp_key'] = list_key
    df_copy['sp_loudness'] = list_loudness
    df_copy['sp_mode'] = list_mode
    df_copy['sp_speechiness'] = list_speechiness
    df_copy['sp_acousticness'] = list_acousticness
    df_copy['sp_instrumentalness'] = list_instrumentalness
    df_copy['sp_liveness'] = list_liveness
    df_copy['sp_valence'] = list_valence
    df_copy['sp_tempo'] = list_tempo
    df_copy['sp_time_signature'] = list_time_signature
    
    return df_copy

# %%
# Add new information to the dataframe
df_sp = get_spotify_audio_features(df_sp, spotify_audio_features)

# Check result
df_sp.head()
# Out:
#        song                      artists              artists_list  \
# 0   Roxanne               Arizona Zervas          [Arizona Zervas]
# 1    Say So                     Doja Cat                [Doja Cat]
# 2  My Oh My  Camila Cabello feat. DaBaby  [Camila Cabello, DaBaby]
# 3      Moon              Kid Francescoli         [Kid Francescoli]
# 4      Vibe               Cookiee Kawaii          [Cookiee Kawaii]
#
#    number_artists                                     spotify_search  \
# 0               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 1               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 2               2  {'tracks': {'href': 'https://api.spotify.com/v...
# 3               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 4               1  {'tracks': {'href': 'https://api.spotify.com/v...
#
#                     sp_id sp_duration_ms sp_popularity sp_release_date  \
# 0  696DnlkuDOXcMAnKlTgXXK         163636            88      2019-10-10
# 1  3Dv1eDb0MEgF93GpLXlucZ         237893            88      2019-11-07
# 2  3yOlyBJuViE2YSGn3nVE1K         170746            82      2019-12-06
# 3  24upABZ8A0sAepfu91sEYr         390638            70      2017-03-03
# 4  4gOgQTv9RYYFZ1uQNnlk3q          83940            72      2019-03-29
#
#   sp_explicit  ... sp_key sp_loudness sp_mode sp_speechiness sp_acousticness  \
# 0        True  ...      6      -5.616       0          0.148          0.0522
# 1        True  ...     11      -4.577       0          0.158           0.256
# 2       False  ...      8      -6.024       1         0.0296           0.018
# 3       False  ...      7     -10.002       1         0.0345           0.288
# 4        True  ...     10      -8.719       1          0.344          0.0635
#
#   sp_instrumentalness sp_liveness sp_valence sp_tempo sp_time_signature
# 0                   0        0.46      0.457  116.735                 5
# 1            3.57e-06      0.0904      0.786  110.962                 4
# 2            1.29e-05      0.0887      0.383  105.046                 4
# 3               0.856       0.102     0.0584  117.986                 4
# 4             0.00932       0.118      0.175  159.947                 4
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Final Dataframe

# %%
df_tracks_sp = df_sp[~(df_sp.sp_id == 'not-found')]

# Check the result
df_tracks_sp
# Out:
#                 song                                         artists  \
# 0            Roxanne                                  Arizona Zervas
# 1             Say So                                        Doja Cat
# 2           My Oh My                     Camila Cabello feat. DaBaby
# 3               Moon                                 Kid Francescoli
# 4               Vibe                                  Cookiee Kawaii
# ..               ...                                             ...
# 64     What the Hell                                   Avril Lavigne
# 65   Towards the Sun                                         Rihanna
# 66  I Think I'm OKAY  Machine Gun Kelly, YUNGBLUD, and Travis Barker
# 67            Myself                                           Bazzi
# 68          Stronger                                      Kanye West
#
#                                     artists_list  number_artists  \
# 0                               [Arizona Zervas]               1
# 1                                     [Doja Cat]               1
# 2                       [Camila Cabello, DaBaby]               2
# 3                              [Kid Francescoli]               1
# 4                               [Cookiee Kawaii]               1
# ..                                           ...             ...
# 64                               [Avril Lavigne]               1
# 65                                     [Rihanna]               1
# 66  [Machine Gun Kelly, YUNGBLUD, Travis Barker]               3
# 67                                       [Bazzi]               1
# 68                                  [Kanye West]               1
#
#                                        spotify_search                   sp_id  \
# 0   {'tracks': {'href': 'https://api.spotify.com/v...  696DnlkuDOXcMAnKlTgXXK
# 1   {'tracks': {'href': 'https://api.spotify.com/v...  3Dv1eDb0MEgF93GpLXlucZ
# 2   {'tracks': {'href': 'https://api.spotify.com/v...  3yOlyBJuViE2YSGn3nVE1K
# 3   {'tracks': {'href': 'https://api.spotify.com/v...  24upABZ8A0sAepfu91sEYr
# 4   {'tracks': {'href': 'https://api.spotify.com/v...  4gOgQTv9RYYFZ1uQNnlk3q
# ..                                                ...                     ...
# 64  {'tracks': {'href': 'https://api.spotify.com/v...  2z4U9d5OAA4YLNXoCgioxo
# 65  {'tracks': {'href': 'https://api.spotify.com/v...  1UuZhGTon3gzXQAJzNa2A4
# 66  {'tracks': {'href': 'https://api.spotify.com/v...  2gTdDMpNxIRFSiu7HutMCg
# 67  {'tracks': {'href': 'https://api.spotify.com/v...  5YLHLxoZsodDWjqSgjhBf3
# 68  {'tracks': {'href': 'https://api.spotify.com/v...  4fzsfWzRhPawzqhX8Qt9F3
#
#    sp_duration_ms sp_popularity sp_release_date sp_explicit  ... sp_key  \
# 0          163636            88      2019-10-10        True  ...      6
# 1          237893            88      2019-11-07        True  ...     11
# 2          170746            82      2019-12-06       False  ...      8
# 3          390638            70      2017-03-03       False  ...      7
# 4           83940            72      2019-03-29        True  ...     10
# ..            ...           ...             ...         ...  ...    ...
# 64         220706            74      2011-03-08       False  ...      6
# 65         273293            55      2015-03-23       False  ...      4
# 66         169397            81      2019-07-05        True  ...      7
# 67         167552            76      2018-04-12       False  ...      9
# 68         311866            80      2007-09-11        True  ...     10
#
#    sp_loudness sp_mode sp_speechiness sp_acousticness sp_instrumentalness  \
# 0       -5.616       0          0.148          0.0522                   0
# 1       -4.577       0          0.158           0.256            3.57e-06
# 2       -6.024       1         0.0296           0.018            1.29e-05
# 3      -10.002       1         0.0345           0.288               0.856
# 4       -8.719       1          0.344          0.0635             0.00932
# ..         ...     ...            ...             ...                 ...
# 64      -3.689       0         0.0548         0.00472              0.0127
# 65      -6.207       0         0.0392          0.0531                   0
# 66      -4.718       1         0.0379          0.0257                   0
# 67      -5.513       0          0.072           0.465            1.12e-06
# 68      -7.858       0          0.153         0.00564                   0
#
#    sp_liveness sp_valence sp_tempo sp_time_signature
# 0         0.46      0.457  116.735                 5
# 1       0.0904      0.786  110.962                 4
# 2       0.0887      0.383  105.046                 4
# 3        0.102     0.0584  117.986                 4
# 4        0.118      0.175  159.947                 4
# ..         ...        ...      ...               ...
# 64        0.14      0.877  149.976                 4
# 65       0.152      0.263   170.18                 4
# 66       0.313      0.277  119.921                 4
# 67      0.0338      0.902  195.918                 4
# 68       0.408       0.49  103.992                 4
#
# [66 rows x 22 columns]

# %%
# Dataframe metadata
df_tracks_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 0 to 68
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   song                 66 non-null     object
#  1   artists              66 non-null     object
#  2   artists_list         66 non-null     object
#  3   number_artists       66 non-null     int64
#  4   spotify_search       66 non-null     object
#  5   sp_id                66 non-null     object
#  6   sp_duration_ms       66 non-null     object
#  7   sp_popularity        66 non-null     object
#  8   sp_release_date      66 non-null     object
#  9   sp_explicit          66 non-null     object
#  10  sp_danceability      66 non-null     object
#  11  sp_energy            66 non-null     object
#  12  sp_key               66 non-null     object
#  13  sp_loudness          66 non-null     object
#  14  sp_mode              66 non-null     object
#  15  sp_speechiness       66 non-null     object
#  16  sp_acousticness      66 non-null     object
#  17  sp_instrumentalness  66 non-null     object
#  18  sp_liveness          66 non-null     object
#  19  sp_valence           66 non-null     object
#  20  sp_tempo             66 non-null     object
#  21  sp_time_signature    66 non-null     object
# dtypes: int64(1), object(21)
# memory usage: 11.9+ KB

# %% [markdown]
# ### Export dataset

# %%
# Export
df_tracks_sp.to_csv('exported_df/sp_tracks_info.csv', index=False)

# %% [markdown]
# ## Artists

# %% [markdown]
# ### Get artists ID

# %%
# Function to add new information in a copy of the dataframe
def get_spotify_artists_id(df):
    
    '''
    Creates a new dataframe about the artists.
    
    Args:
    -----
        df (Pandas DataFrame): a dataframe containing the songs and their artists
    
    Returns:
    --------
        df_artists_id (Pandas DataFrame): a new dataframe with the name and Spotify ID of the artists
    '''
    
    # Create auxiliary empty dictionary
    dict_artists_ids = {}
      
    # Check for each row of the dataframe
    for index in df.index:
                      
        # Information necessary from the dataframe to use during the process
        song_name = df.iloc[index, 0][:3].lower()
        artists_list = [artist.lower() for artist in df.iloc[index, 2]]
        total_artists = df.iloc[index, 3]
        mask = df.iloc[index, 4]['tracks']['items']
        added = 0
        
        # For each track it was listed 50 tracks related to the query 
        for idx, each_found in enumerate(mask):
                
            # Information necessary from the Spotify API to use during the process
            track_name = mask[idx]['name'].lower()
            n_artists = len(mask[idx]['artists'])
            first_artist_name = mask[idx]['artists'][0]['name'].lower()
            
            # Check if the name of the song, the artists from both sources match and if an information about the
            # song has been added to the final lists 
            if ((song_name in track_name) & (total_artists == n_artists) & 
                ((first_artist_name in artists_list) | (artists_list[0][:5] in first_artist_name)) & (added == 0)
                & (df.iloc[index, 5] != 'not-found')):
                
                for artist in mask[idx]['artists']:
                    artist_name = artist['name']
                    artist_id = artist['id']
                        
                    # Add to dict
                    dict_artists_ids[artist_name] = artist_id
                    
    # Create a Pandas DataFrame
    
    df_artists_id = pd.DataFrame(dict_artists_ids.items(), columns=['artist', 'sp_id'])
                    
    return df_artists_id

# %%
# Create a Pandas DataFrame with artists
df_artists_sp = get_spotify_artists_id(df_sp)

# Check result
df_artists_sp
# Out:
#                artist                   sp_id
# 0      Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1            Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2      Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3              DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4     Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
# ..                ...                     ...
# 83  Machine Gun Kelly  6TIYQ3jFPwQSRmorSezPxX
# 84           YUNGBLUD  6Ad91Jof8Niiw0lGLLi3NW
# 85      Travis Barker  4exLIFE8sISLr28sqG1qNX
# 86              Bazzi  4GvEc3ANtPPjt1ZJllr5Zl
# 87         Kanye West  5K4W6rqBFWDnAN6FQUkS6x
#
# [88 rows x 2 columns]

# %%
# Search in the API wrapper
spotify_artists_info = [sp.artist(artist) for artist in  tqdm(df_artists_sp.sp_id)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=88.0), HTML(value='')))

# %%
# Add a column in the dataframe with the data that were just collected
df_artists_sp['spotify_artist'] = spotify_artists_info

# Check the result
df_artists_sp.head()
# Out:
#             artist                   sp_id  \
# 0   Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1         Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2   Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3           DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4  Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
#
#                                       spotify_artist
# 0  {'external_urls': {'spotify': 'https://open.sp...
# 1  {'external_urls': {'spotify': 'https://open.sp...
# 2  {'external_urls': {'spotify': 'https://open.sp...
# 3  {'external_urls': {'spotify': 'https://open.sp...
# 4  {'external_urls': {'spotify': 'https://open.sp...

# %% [markdown]
# ### Add information about the artists to the dataframe

# %%
# Function to add new information in a copy of the dataframe
def get_spotify_artist_info(df):
    
    '''
    Adds information about the artists to a copy of the dataframe.
    
    Args:
    -----
        df (Pandas DataFrame): a dataframe containing the artists and their Spotify ID
    
    Returns:
    --------
        df_copy (Pandas DataFrame): a copy of the dataframe with some new information appended
    '''
    
    # Create auxiliary empty lists (final lists)
    list_spotify_artist_genres = []
    list_spotify_artist_popularity = []
    list_spotify_artist_followers = []
    
    # Check for each row of the dataframe
    for index in df.index:
        
        sp_id = df.iloc[index, 1]
        mask = df.iloc[index, 2]
        search_sp_id = mask['id']
        #artist_name = mask['name']
        
        # Check if 'id's match
        if sp_id == search_sp_id:
            #print(f'{index} - {artist_name}: OK - {n_artist}')
            
            search_sp_genres = mask['genres']
            list_spotify_artist_genres.append(search_sp_genres)
            
            search_sp_popularity = mask['popularity']
            list_spotify_artist_popularity.append(search_sp_popularity)
            
            search_sp_followers = mask['followers']['total']
            list_spotify_artist_followers.append(search_sp_followers)
    
    # Make a copy of the dataframe
    df_copy = df.copy()
    
    # Add columns with the desired information
    # Not an inplace process
    df_copy['sp_genres'] = list_spotify_artist_genres
    df_copy['sp_popularity'] = list_spotify_artist_popularity
    df_copy['sp_followers'] = list_spotify_artist_followers
                    
    return df_copy

# %%
# Add desired information to the dataframe
df_artists_sp = get_spotify_artist_info(df_artists_sp)

# Check the result
df_artists_sp.head()
# Out:
#             artist                   sp_id  \
# 0   Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1         Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2   Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3           DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4  Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
#
#                                       spotify_artist  \
# 0  {'external_urls': {'spotify': 'https://open.sp...
# 1  {'external_urls': {'spotify': 'https://open.sp...
# 2  {'external_urls': {'spotify': 'https://open.sp...
# 3  {'external_urls': {'spotify': 'https://open.sp...
# 4  {'external_urls': {'spotify': 'https://open.sp...
#
#                                            sp_genres  sp_popularity  \
# 0                   [pop rap, rap, rhode island rap]             80
# 1                                    [la indie, pop]             88
# 2                    [dance pop, pop, post-teen pop]             87
# 3                      [north carolina hip hop, rap]             95
# 4  [electronica, french indie pop, french indietr...             61
#
#    sp_followers
# 0        486779
# 1       3445699
# 2      17989469
# 3       4326193
# 4         82296

# %% [markdown]
# ### Final Dataframe

# %%
df_artists_sp
# Out:
#                artist                   sp_id  \
# 0      Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1            Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2      Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3              DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4     Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
# ..                ...                     ...
# 83  Machine Gun Kelly  6TIYQ3jFPwQSRmorSezPxX
# 84           YUNGBLUD  6Ad91Jof8Niiw0lGLLi3NW
# 85      Travis Barker  4exLIFE8sISLr28sqG1qNX
# 86              Bazzi  4GvEc3ANtPPjt1ZJllr5Zl
# 87         Kanye West  5K4W6rqBFWDnAN6FQUkS6x
#
#                                        spotify_artist  \
# 0   {'external_urls': {'spotify': 'https://open.sp...
# 1   {'external_urls': {'spotify': 'https://open.sp...
# 2   {'external_urls': {'spotify': 'https://open.sp...
# 3   {'external_urls': {'spotify': 'https://open.sp...
# 4   {'external_urls': {'spotify': 'https://open.sp...
# ..                                                ...
# 83  {'external_urls': {'spotify': 'https://open.sp...
# 84  {'external_urls': {'spotify': 'https://open.sp...
# 85  {'external_urls': {'spotify': 'https://open.sp...
# 86  {'external_urls': {'spotify': 'https://open.sp...
# 87  {'external_urls': {'spotify': 'https://open.sp...
#
#                                             sp_genres  sp_popularity  \
# 0                    [pop rap, rap, rhode island rap]             80
# 1                                     [la indie, pop]             88
# 2                     [dance pop, pop, post-teen pop]             87
# 3                       [north carolina hip hop, rap]             95
# 4   [electronica, french indie pop, french indietr...             61
# ..                                                ...            ...
# 83                       [ohio hip hop, pop rap, rap]             86
# 84  [british indie rock, modern alternative rock, ...             78
# 85                                         [rap rock]             77
# 86                               [pop, post-teen pop]             83
# 87                                 [chicago rap, rap]             91
#
#     sp_followers
# 0         486779
# 1        3445699
# 2       17989469
# 3        4326193
# 4          82296
# ..           ...
# 83       2454191
# 84       1085134
# 85        252326
# 86       3671755
# 87      12428005
#
# [88 rows x 6 columns]

# %% [markdown]
# ### Export the dataframe

# %%
# Export
df_artists_sp.to_csv('exported_df/sp_artists_info.csv', index=False)

# %% [markdown]
# ## Playlists

# %%
# Search in the API wrapper
spotify_tiktok = sp.search(q='tiktok', type='playlist', limit=50)

# %%
# Check the number of playlists
len(spotify_tiktok['playlists']['items'])
# Out:
# 50

# %% [markdown]
# ## Get playlist ID

# %%
# Get the playlists IDs and convert to a dataframe
sp_playlists = pd.DataFrame([playlist['id'] for playlist in spotify_tiktok['playlists']['items']], columns=['sp_playlist_id'])
sp_playlists.head()
# Out:
#            sp_playlist_id
# 0  37i9dQZF1DX2L0iB23Enbq
# 1  65LdqYCLcsV0lJoxpeQ6fW
# 2  0JFatPoPq82gNcPa4esOzj
# 3  2NNzPH70CakBbbU8JHrZRG
# 4  4FLeoROn5GT7n2tZq5XB4V

# %% [markdown]
# ## Get information about the playlists

# %%
# Get additional information about the playlists
sp_playlists['sp_playlist_info'] = [sp.playlist(id) for id in tqdm(sp_playlists.sp_playlist_id)]

# Check the result
sp_playlists.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-272-158d2a112b74> in <module>
#       1 sp_playlists['sp_playlist_info'] = [sp.playlist(id) for id in tqdm(sp_playlists.sp_playlist_id)]
# ----> 2 sp_playlist.head()
#
# NameError: name 'sp_playlist' is not defined

# %% [markdown]
# # Chartmetric

# %% [markdown]
# ## Connecting to the API

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
def get_token_cmc():
    url = "https://api.chartmetric.com/api/token"
    payload = r'{"refreshtoken":"%s"}' % os.getenv('chartmetric_rftoken')

    headers = {
      'Content-Type': 'application/json',
      'Cookie': 'connect.sid=s%3A96446210-f75b-11ea-bb65-c97242076514.wtHGb%2BZnACRtIERUXXeoBVsOmhNDPPnBzgPW9UL%2Bhpc'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    print(response)
    
    token = re.findall("[A-Za-z0-9._-]+", response.text)[1]
    
    return token

# %%
token = get_token_cmc()
# Out:
# <Response [200]>

# %% [markdown]
# ## Songs

# %%
# Create a dataframe with songs for the Chartmetric dataset
df_cmc_tracks = df_sp.iloc[:, 0:6].drop(columns='spotify_search')
df_cmc_tracks
# Out:
#                 song                                         artists  \
# 0            Roxanne                                  Arizona Zervas
# 1             Say So                                        Doja Cat
# 2           My Oh My                     Camila Cabello feat. DaBaby
# 3               Moon                                 Kid Francescoli
# 4               Vibe                                  Cookiee Kawaii
# ..               ...                                             ...
# 64     What the Hell                                   Avril Lavigne
# 65   Towards the Sun                                         Rihanna
# 66  I Think I'm OKAY  Machine Gun Kelly, YUNGBLUD, and Travis Barker
# 67            Myself                                           Bazzi
# 68          Stronger                                      Kanye West
#
#                                     artists_list  number_artists  \
# 0                               [Arizona Zervas]               1
# 1                                     [Doja Cat]               1
# 2                       [Camila Cabello, DaBaby]               2
# 3                              [Kid Francescoli]               1
# 4                               [Cookiee Kawaii]               1
# ..                                           ...             ...
# 64                               [Avril Lavigne]               1
# 65                                     [Rihanna]               1
# 66  [Machine Gun Kelly, YUNGBLUD, Travis Barker]               3
# 67                                       [Bazzi]               1
# 68                                  [Kanye West]               1
#
#                      sp_id
# 0   696DnlkuDOXcMAnKlTgXXK
# 1   3Dv1eDb0MEgF93GpLXlucZ
# 2   3yOlyBJuViE2YSGn3nVE1K
# 3   24upABZ8A0sAepfu91sEYr
# 4   4gOgQTv9RYYFZ1uQNnlk3q
# ..                     ...
# 64  2z4U9d5OAA4YLNXoCgioxo
# 65  1UuZhGTon3gzXQAJzNa2A4
# 66  2gTdDMpNxIRFSiu7HutMCg
# 67  5YLHLxoZsodDWjqSgjhBf3
# 68  4fzsfWzRhPawzqhX8Qt9F3
#
# [69 rows x 5 columns]

# %% [markdown]
# ### Get Chartmetric track ID

# %%
def get_cmc_id_spotify(query: str, limit=10, offset=0):
    
    '''
    Searches for Chartmetric track ID using Spotify ID
    
    Args: spotify ID
    ------
    
    Returns: json
    '''
    
    search = f'https://open.spotify.com/track/{query}'
    url = f'https://api.chartmetric.com/api/search?q={search}&limit={limit}&offset={offset}&type=tracks'
    
    headers = {
    'Authorization': 'Bearer ' + token
    }
    
    response = requests.get(url, headers=headers)
    
    return response.json()

# %%
cmc_tracks_id = [get_cmc_id_spotify(id) if id != 'not-found' else 'not-found' for id in tqdm(df_cmc_tracks.sp_id)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=69.0), HTML(value='')))

# %%
len(cmc_tracks_id)
# Out:
# 69

# %%
df_cmc_tracks['cmc_song_seach'] = cmc_tracks_id
df_cmc_tracks
# Out:
#                 song                                         artists  \
# 0            Roxanne                                  Arizona Zervas
# 1             Say So                                        Doja Cat
# 2           My Oh My                     Camila Cabello feat. DaBaby
# 3               Moon                                 Kid Francescoli
# 4               Vibe                                  Cookiee Kawaii
# ..               ...                                             ...
# 64     What the Hell                                   Avril Lavigne
# 65   Towards the Sun                                         Rihanna
# 66  I Think I'm OKAY  Machine Gun Kelly, YUNGBLUD, and Travis Barker
# 67            Myself                                           Bazzi
# 68          Stronger                                      Kanye West
#
#                                     artists_list  number_artists  \
# 0                               [Arizona Zervas]               1
# 1                                     [Doja Cat]               1
# 2                       [Camila Cabello, DaBaby]               2
# 3                              [Kid Francescoli]               1
# 4                               [Cookiee Kawaii]               1
# ..                                           ...             ...
# 64                               [Avril Lavigne]               1
# 65                                     [Rihanna]               1
# 66  [Machine Gun Kelly, YUNGBLUD, Travis Barker]               3
# 67                                       [Bazzi]               1
# 68                                  [Kanye West]               1
#
#                      sp_id                                     cmc_song_seach
# 0   696DnlkuDOXcMAnKlTgXXK  {'obj': {'tracks': [{'id': 27228348, 'name': '...
# 1   3Dv1eDb0MEgF93GpLXlucZ  {'obj': {'tracks': [{'id': 26951096, 'name': '...
# 2   3yOlyBJuViE2YSGn3nVE1K  {'obj': {'tracks': [{'id': 27597895, 'name': '...
# 3   24upABZ8A0sAepfu91sEYr  {'obj': {'tracks': [{'id': 12263271, 'name': '...
# 4   4gOgQTv9RYYFZ1uQNnlk3q  {'obj': {'tracks': [{'id': 25138356, 'name': '...
# ..                     ...                                                ...
# 64  2z4U9d5OAA4YLNXoCgioxo  {'obj': {'tracks': [{'id': 15674355, 'name': '...
# 65  1UuZhGTon3gzXQAJzNa2A4  {'obj': {'tracks': [{'id': 13795060, 'name': '...
# 66  2gTdDMpNxIRFSiu7HutMCg  {'obj': {'tracks': [{'id': 23903635, 'name': "...
# 67  5YLHLxoZsodDWjqSgjhBf3  {'obj': {'tracks': [{'id': 19040153, 'name': '...
# 68  4fzsfWzRhPawzqhX8Qt9F3  {'obj': {'tracks': [{'id': 15906456, 'name': '...
#
# [69 rows x 6 columns]

# %%
df_cmc_tracks['cmc_id'] = [cmc_search['obj']['tracks'][0]['id'] if df_cmc_tracks.iloc[index, 4] != 'not-found' 
                           else 'not-found' for index, cmc_search in enumerate(df_cmc_tracks.cmc_song_seach)]

df_cmc_tracks.head()
# Out:
#        song                      artists              artists_list  \
# 0   Roxanne               Arizona Zervas          [Arizona Zervas]
# 1    Say So                     Doja Cat                [Doja Cat]
# 2  My Oh My  Camila Cabello feat. DaBaby  [Camila Cabello, DaBaby]
# 3      Moon              Kid Francescoli         [Kid Francescoli]
# 4      Vibe               Cookiee Kawaii          [Cookiee Kawaii]
#
#    number_artists                   sp_id  \
# 0               1  696DnlkuDOXcMAnKlTgXXK
# 1               1  3Dv1eDb0MEgF93GpLXlucZ
# 2               2  3yOlyBJuViE2YSGn3nVE1K
# 3               1  24upABZ8A0sAepfu91sEYr
# 4               1  4gOgQTv9RYYFZ1uQNnlk3q
#
#                                       cmc_song_seach    cmc_id
# 0  {'obj': {'tracks': [{'id': 27228348, 'name': '...  27228348
# 1  {'obj': {'tracks': [{'id': 26951096, 'name': '...  26951096
# 2  {'obj': {'tracks': [{'id': 27597895, 'name': '...  27597895
# 3  {'obj': {'tracks': [{'id': 12263271, 'name': '...  12263271
# 4  {'obj': {'tracks': [{'id': 25138356, 'name': '...  25138356

# %% [markdown]
# ### Get track metadata

# %%
def get_cmc_metadata(cmc_id: str):
    
    
    
    url = f'https://api.chartmetric.com/api/track/{cmc_id}'
    
    headers = {
    'Authorization': 'Bearer ' + token
    }
    
    response = requests.get(url, headers=headers)
    
    return response.json()

# %%
cmc_track_metadata = [get_cmc_metadata(id) if id != 'not-found' else 'not-found' for id in tqdm(df_cmc_tracks.cmc_id)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=69.0), HTML(value='')))

# %%
df_cmc_tracks['cmc_track_metadata'] = cmc_track_metadata

# %%
df_cmc_tracks.head()
# Out:
#        song                      artists              artists_list  \
# 0   Roxanne               Arizona Zervas          [Arizona Zervas]
# 1    Say So                     Doja Cat                [Doja Cat]
# 2  My Oh My  Camila Cabello feat. DaBaby  [Camila Cabello, DaBaby]
# 3      Moon              Kid Francescoli         [Kid Francescoli]
# 4      Vibe               Cookiee Kawaii          [Cookiee Kawaii]
#
#    number_artists                   sp_id  \
# 0               1  696DnlkuDOXcMAnKlTgXXK
# 1               1  3Dv1eDb0MEgF93GpLXlucZ
# 2               2  3yOlyBJuViE2YSGn3nVE1K
# 3               1  24upABZ8A0sAepfu91sEYr
# 4               1  4gOgQTv9RYYFZ1uQNnlk3q
#
#                                       cmc_song_seach    cmc_id  \
# 0  {'obj': {'tracks': [{'id': 27228348, 'name': '...  27228348
# 1  {'obj': {'tracks': [{'id': 26951096, 'name': '...  26951096
# 2  {'obj': {'tracks': [{'id': 27597895, 'name': '...  27597895
# 3  {'obj': {'tracks': [{'id': 12263271, 'name': '...  12263271
# 4  {'obj': {'tracks': [{'id': 25138356, 'name': '...  25138356
#
#                                   cmc_track_metadata
# 0  {'obj': {'id': 27228348, 'name': 'ROXANNE', 'i...
# 1  {'obj': {'id': 26951096, 'name': 'Say So', 'is...
# 2  {'obj': {'id': 27597895, 'name': 'My Oh My', '...
# 3  {'obj': {'id': 12263271, 'name': 'Moon', 'isrc...
# 4  {'obj': {'id': 25138356, 'name': 'Vibe', 'isrc...

# %% [markdown]
# ### Get track stats - TikTok

# %%
def get_cmc_track_stats_tiktok(cmc_id, since="2020-01-01"):
    
    
    
    url = f'https://api.chartmetric.com/api/track/{cmc_id}/tiktok/stats?since={since}'
    
    headers = {
    'Authorization': 'Bearer ' + token
    }
    
    response = requests.get(url, headers=headers)
    
    return response.json()

# %%
cmc_track_stats_tiktok = [get_cmc_track_stats_tiktok(id) if id != 'not-found' else 'not-found' for id in tqdm(df_cmc_tracks.cmc_id)]

# %%
df_cmc_tracks['cmc_track_stats_tiktok'] = cmc_track_stats_tiktok
df_cmc_tracks.head()

# %% [markdown]
# ### Export dataset

# %%
df_cmc_tracks.to_csv('cmc_tracks_info.csv', index=False)

# %% [markdown]
# ## Artists

# %%
df_cmc_artists = df_artists.drop(columns=['spotify_artist'])
df_cmc_artists
# Out:
#                artist                   sp_id  \
# 0      Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1            Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2      Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3              DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4     Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
# ..                ...                     ...
# 83  Machine Gun Kelly  6TIYQ3jFPwQSRmorSezPxX
# 84           YUNGBLUD  6Ad91Jof8Niiw0lGLLi3NW
# 85      Travis Barker  4exLIFE8sISLr28sqG1qNX
# 86              Bazzi  4GvEc3ANtPPjt1ZJllr5Zl
# 87         Kanye West  5K4W6rqBFWDnAN6FQUkS6x
#
#                                             sp_genres  sp_popularity  \
# 0                    [pop rap, rap, rhode island rap]             80
# 1                                     [la indie, pop]             88
# 2                     [dance pop, pop, post-teen pop]             87
# 3                       [north carolina hip hop, rap]             95
# 4   [electronica, french indie pop, french indietr...             61
# ..                                                ...            ...
# 83                       [ohio hip hop, pop rap, rap]             86
# 84  [british indie rock, modern alternative rock, ...             78
# 85                                         [rap rock]             77
# 86                               [pop, post-teen pop]             83
# 87                                 [chicago rap, rap]             91
#
#     sp_followers
# 0         486779
# 1        3445699
# 2       17989469
# 3        4326193
# 4          82296
# ..           ...
# 83       2454191
# 84       1085134
# 85        252326
# 86       3671755
# 87      12428005
#
# [88 rows x 5 columns]

# %% [markdown]
# ### Get Artists IDs

# %%
def cmc_search_artist_spotify(query: str, limit=10, offset=0):
    
    '''
    Searches for Chartmetric artist ID using Spotify ID
    
    Args: spotify ID
    ------
    
    Returns: json
    '''
    
    search = f'https://open.spotify.com/artist/{query}'
    url = f'https://api.chartmetric.com/api/search?q={search}&limit={limit}&offset={offset}&type=artists'
    
    headers = {
    'Authorization': 'Bearer ' + token
    }
    
    response = requests.get(url, headers=headers)
    
    return response.json()

# %%
cmc_artist_id = [cmc_search_artist_spotify(id) for id in tqdm(df_cmc_artists['sp_id'])]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=88.0), HTML(value='')))

# %%
df_cmc_artists['cmc_search'] = cmc_artist_id

# %%
df_cmc_artists.head()
# Out:
#             artist                   sp_id  \
# 0   Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1         Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2   Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3           DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4  Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
#
#                                            sp_genres  sp_popularity  \
# 0                   [pop rap, rap, rhode island rap]             80
# 1                                    [la indie, pop]             88
# 2                    [dance pop, pop, post-teen pop]             87
# 3                      [north carolina hip hop, rap]             95
# 4  [electronica, french indie pop, french indietr...             61
#
#    sp_followers                                         cmc_search
# 0        486779  {'obj': {'artists': [{'id': 64150, 'name': 'Ar...
# 1       3445699  {'obj': {'artists': [{'id': 217671, 'name': 'D...
# 2      17989469  {'obj': {'artists': [{'id': 454302, 'name': 'C...
# 3       4326193  {'obj': {'artists': [{'id': 398544, 'name': 'D...
# 4         82296  {'obj': {'artists': [{'id': 147365, 'name': 'K...

# %%
df_cmc_artists.cmc_search[0]['obj']['artists'][0]
# Out:
# {'id': 64150,
#  'name': 'Arizona Zervas',
#  'image_url': 'https://i.scdn.co/image/d549aadbb8b3a254fdc8e5ac93535a706463dce6',
#  'isni': None,
#  'code2': 'us',
#  'hometown_city': None,
#  'current_city': None,
#  'sp_followers': 485529,
#  'sp_popularity': 80,
#  'sp_monthly_listeners': 15313268,
#  'deezer_fans': 29274,
#  'tags': ['pop', 'pop rap'],
#  'spotify_artist_ids': ['0vRvGUQVUjytro0xpb26bs'],
#  'itunes_artist_ids': [1026196272],
#  'deezer_artist_ids': ['8650540'],
#  'cm_artist_rank': 353,
#  'amazon_artist_ids': ['B013CV8F1E']}

# %%
df_cmc_artists['cmc_id'] = [search['obj']['artists'][0]['id'] for search in df_cmc_artists.cmc_search]
df_cmc_artists
# Out:
#                artist                   sp_id  \
# 0      Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1            Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2      Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3              DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4     Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
# ..                ...                     ...
# 83  Machine Gun Kelly  6TIYQ3jFPwQSRmorSezPxX
# 84           YUNGBLUD  6Ad91Jof8Niiw0lGLLi3NW
# 85      Travis Barker  4exLIFE8sISLr28sqG1qNX
# 86              Bazzi  4GvEc3ANtPPjt1ZJllr5Zl
# 87         Kanye West  5K4W6rqBFWDnAN6FQUkS6x
#
#                                             sp_genres  sp_popularity  \
# 0                    [pop rap, rap, rhode island rap]             80
# 1                                     [la indie, pop]             88
# 2                     [dance pop, pop, post-teen pop]             87
# 3                       [north carolina hip hop, rap]             95
# 4   [electronica, french indie pop, french indietr...             61
# ..                                                ...            ...
# 83                       [ohio hip hop, pop rap, rap]             86
# 84  [british indie rock, modern alternative rock, ...             78
# 85                                         [rap rock]             77
# 86                               [pop, post-teen pop]             83
# 87                                 [chicago rap, rap]             91
#
#     sp_followers                                         cmc_search  cmc_id
# 0         486779  {'obj': {'artists': [{'id': 64150, 'name': 'Ar...   64150
# 1        3445699  {'obj': {'artists': [{'id': 217671, 'name': 'D...  217671
# 2       17989469  {'obj': {'artists': [{'id': 454302, 'name': 'C...  454302
# 3        4326193  {'obj': {'artists': [{'id': 398544, 'name': 'D...  398544
# 4          82296  {'obj': {'artists': [{'id': 147365, 'name': 'K...  147365
# ..           ...                                                ...     ...
# 83       2454191  {'obj': {'artists': [{'id': 3991, 'name': 'Mac...    3991
# 84       1085134  {'obj': {'artists': [{'id': 558951, 'name': 'Y...  558951
# 85        252326  {'obj': {'artists': [{'id': 216839, 'name': 'T...  216839
# 86       3671755  {'obj': {'artists': [{'id': 213807, 'name': 'B...  213807
# 87      12428005  {'obj': {'artists': [{'id': 1845, 'name': 'Kan...    1845
#
# [88 rows x 7 columns]

# %% [markdown]
# ### Get artist metadata

# %%
def get_cmc_artist_metadata(cmc_id: str):
    
    
    
    url = f'https://api.chartmetric.com/api/artist/{cmc_id}'
    
    headers = {
    'Authorization': 'Bearer ' + token
    }
    
    response = requests.get(url, headers=headers)
    
    return response.json()

# %%
cmc_art_metadata = [get_cmc_artist_metadata(id) for id in tqdm(df_cmc_artists.cmc_id)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=88.0), HTML(value='')))

# %%
df_cmc_artists['cmc_art_metadata'] = cmc_art_metadata
df_cmc_artists
# Out:
#                artist                   sp_id  \
# 0      Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1            Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2      Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3              DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4     Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
# ..                ...                     ...
# 83  Machine Gun Kelly  6TIYQ3jFPwQSRmorSezPxX
# 84           YUNGBLUD  6Ad91Jof8Niiw0lGLLi3NW
# 85      Travis Barker  4exLIFE8sISLr28sqG1qNX
# 86              Bazzi  4GvEc3ANtPPjt1ZJllr5Zl
# 87         Kanye West  5K4W6rqBFWDnAN6FQUkS6x
#
#                                             sp_genres  sp_popularity  \
# 0                    [pop rap, rap, rhode island rap]             80
# 1                                     [la indie, pop]             88
# 2                     [dance pop, pop, post-teen pop]             87
# 3                       [north carolina hip hop, rap]             95
# 4   [electronica, french indie pop, french indietr...             61
# ..                                                ...            ...
# 83                       [ohio hip hop, pop rap, rap]             86
# 84  [british indie rock, modern alternative rock, ...             78
# 85                                         [rap rock]             77
# 86                               [pop, post-teen pop]             83
# 87                                 [chicago rap, rap]             91
#
#     sp_followers                                         cmc_search  cmc_id  \
# 0         486779  {'obj': {'artists': [{'id': 64150, 'name': 'Ar...   64150
# 1        3445699  {'obj': {'artists': [{'id': 217671, 'name': 'D...  217671
# 2       17989469  {'obj': {'artists': [{'id': 454302, 'name': 'C...  454302
# 3        4326193  {'obj': {'artists': [{'id': 398544, 'name': 'D...  398544
# 4          82296  {'obj': {'artists': [{'id': 147365, 'name': 'K...  147365
# ..           ...                                                ...     ...
# 83       2454191  {'obj': {'artists': [{'id': 3991, 'name': 'Mac...    3991
# 84       1085134  {'obj': {'artists': [{'id': 558951, 'name': 'Y...  558951
# 85        252326  {'obj': {'artists': [{'id': 216839, 'name': 'T...  216839
# 86       3671755  {'obj': {'artists': [{'id': 213807, 'name': 'B...  213807
# 87      12428005  {'obj': {'artists': [{'id': 1845, 'name': 'Kan...    1845
#
#                                      cmc_art_metadata
# 0   {'obj': {'id': 64150, 'name': 'Arizona Zervas'...
# 1   {'obj': {'id': 217671, 'name': 'Doja Cat', 'cr...
# 2   {'obj': {'id': 454302, 'name': 'Camila Cabello...
# 3   {'obj': {'id': 398544, 'name': 'DaBaby', 'crea...
# 4   {'obj': {'id': 147365, 'name': 'Kid Francescol...
# ..                                                ...
# 83  {'obj': {'id': 3991, 'name': 'Machine Gun Kell...
# 84  {'obj': {'id': 558951, 'name': 'YUNGBLUD', 'cr...
# 85  {'obj': {'id': 216839, 'name': 'Travis Barker'...
# 86  {'obj': {'id': 213807, 'name': 'Bazzi', 'creat...
# 87  {'obj': {'id': 1845, 'name': 'Kanye West', 'cr...
#
# [88 rows x 8 columns]

# %% [markdown]
# ### Get spotify Monthly Listeners by City

# %%
def get_cmc_artist_sp_city(cmc_id: str):
    
    
    
    url = f'https://api.chartmetric.com/api/artist/{cmc_id}/where-people-listen'
    
    headers = {
    'Authorization': 'Bearer ' + token
    }
    
    response = requests.get(url, headers=headers)
    
    return response.json()

# %%
cmc_art_sp_city = [get_cmc_artist_sp_city(id) for id in tqdm(df_cmc_artists.cmc_id)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=88.0), HTML(value='')))
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-236-d45758cc1436> in <module>
# ----> 1 cmc_art_sp_city = [get_cmc_artist_sp_city(id) for id in tqdm(df_cmc_artists.cmc_id)]
#
# <ipython-input-236-d45758cc1436> in <listcomp>(.0)
# ----> 1 cmc_art_sp_city = [get_cmc_artist_sp_city(id) for id in tqdm(df_cmc_artists.cmc_id)]
#
# <ipython-input-235-55cf51b905f7> in get_cmc_artist_sp_city(cmc_id)
#      11     response = requests.get(url, headers=headers)
#      12
# ---> 13     return response.json()
#
# c:\users\gabsn\envs\ds\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# c:\users\gabsn\appdata\local\programs\python\python38\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# c:\users\gabsn\appdata\local\programs\python\python38\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\users\gabsn\appdata\local\programs\python\python38\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df_cmc_artists['cmc_art_sp_city'] = cmc_art_sp_city
df_cmc_artists.head()

# %% [markdown]
# ## Tiktok Audience Data

# %%
def get_cmc_artist_tiktok_audience_data(cmc_id: str):
    
    
    
    url = f'https://api.chartmetric.com/api/artist/{cmc_id}/tiktok-audience-stats'
    
    headers = {
    'Authorization': 'Bearer ' + token
    }
    
    response = requests.get(url, headers=headers)
    
    return response.json()

# %%
cmc_art_tiktok_audience = [get_cmc_artist_tiktok_audience_data(id) for id in tqdm(df_cmc_artists.cmc_id)]

# %%
df_cmc_artists['cmc_art_tiktok_audience'] = cmc_art_tiktok_audience
df_cmc_artists.head()

# %% [markdown]
# ### Export dataset

# %%
df_cmc_artists.to_csv('cmc_artists.csv', index=False)

# %%
df_teste2 = pd.read_csv('cmc_artists.csv')
df_teste2

# %% [markdown]
# # Charts

# %%
def get_cmc_tiktok_charts(date):
    
    
    
    url = f'https://api.chartmetric.com/api/charts/tiktok/tracks?date={date}&interval=weekly'
    
    headers = {
    'Authorization': 'Bearer ' + token
    }
    
    response = requests.get(url, headers=headers)
    
    return response.json()

# %%
cmc_tiktok_chart = get_cmc_tiktok_charts('2020-09-08')

# %%
df_cmc_chart = pd.DataFrame(cmc_tiktok_chart).reset_index()
df_cmc_chart.to_csv('cmc_chart.csv', index=False)

# %% [markdown]
# # Final Dataframe

# %% [markdown]
# ## Songs

# %% [markdown]
# ### Songs - Spotify

# %%
# Check the dataframe
df_tracks_sp.head()
# Out:
#        song                      artists              artists_list  \
# 0   Roxanne               Arizona Zervas          [Arizona Zervas]
# 1    Say So                     Doja Cat                [Doja Cat]
# 2  My Oh My  Camila Cabello feat. DaBaby  [Camila Cabello, DaBaby]
# 3      Moon              Kid Francescoli         [Kid Francescoli]
# 4      Vibe               Cookiee Kawaii          [Cookiee Kawaii]
#
#    number_artists                                     spotify_search  \
# 0               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 1               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 2               2  {'tracks': {'href': 'https://api.spotify.com/v...
# 3               1  {'tracks': {'href': 'https://api.spotify.com/v...
# 4               1  {'tracks': {'href': 'https://api.spotify.com/v...
#
#                     sp_id sp_duration_ms sp_popularity sp_release_date  \
# 0  696DnlkuDOXcMAnKlTgXXK         163636            88      2019-10-10
# 1  3Dv1eDb0MEgF93GpLXlucZ         237893            88      2019-11-07
# 2  3yOlyBJuViE2YSGn3nVE1K         170746            82      2019-12-06
# 3  24upABZ8A0sAepfu91sEYr         390638            70      2017-03-03
# 4  4gOgQTv9RYYFZ1uQNnlk3q          83940            72      2019-03-29
#
#   sp_explicit  ... sp_key sp_loudness sp_mode sp_speechiness sp_acousticness  \
# 0        True  ...      6      -5.616       0          0.148          0.0522
# 1        True  ...     11      -4.577       0          0.158           0.256
# 2       False  ...      8      -6.024       1         0.0296           0.018
# 3       False  ...      7     -10.002       1         0.0345           0.288
# 4        True  ...     10      -8.719       1          0.344          0.0635
#
#   sp_instrumentalness sp_liveness sp_valence sp_tempo sp_time_signature
# 0                   0        0.46      0.457  116.735                 5
# 1            3.57e-06      0.0904      0.786  110.962                 4
# 2            1.29e-05      0.0887      0.383  105.046                 4
# 3               0.856       0.102     0.0584  117.986                 4
# 4             0.00932       0.118      0.175  159.947                 4
#
# [5 rows x 22 columns]

# %%
# Filter only the songs that were found
df_tracks_sp_found = df_tracks_sp[df_tracks_sp.sp_id != 'not-found']

# Check the result
df_tracks_sp_found
# Out:
#                 song                                         artists  \
# 0            Roxanne                                  Arizona Zervas
# 1             Say So                                        Doja Cat
# 2           My Oh My                     Camila Cabello feat. DaBaby
# 3               Moon                                 Kid Francescoli
# 4               Vibe                                  Cookiee Kawaii
# ..               ...                                             ...
# 64     What the Hell                                   Avril Lavigne
# 65   Towards the Sun                                         Rihanna
# 66  I Think I'm OKAY  Machine Gun Kelly, YUNGBLUD, and Travis Barker
# 67            Myself                                           Bazzi
# 68          Stronger                                      Kanye West
#
#                                     artists_list  number_artists  \
# 0                               [Arizona Zervas]               1
# 1                                     [Doja Cat]               1
# 2                       [Camila Cabello, DaBaby]               2
# 3                              [Kid Francescoli]               1
# 4                               [Cookiee Kawaii]               1
# ..                                           ...             ...
# 64                               [Avril Lavigne]               1
# 65                                     [Rihanna]               1
# 66  [Machine Gun Kelly, YUNGBLUD, Travis Barker]               3
# 67                                       [Bazzi]               1
# 68                                  [Kanye West]               1
#
#                                        spotify_search                   sp_id  \
# 0   {'tracks': {'href': 'https://api.spotify.com/v...  696DnlkuDOXcMAnKlTgXXK
# 1   {'tracks': {'href': 'https://api.spotify.com/v...  3Dv1eDb0MEgF93GpLXlucZ
# 2   {'tracks': {'href': 'https://api.spotify.com/v...  3yOlyBJuViE2YSGn3nVE1K
# 3   {'tracks': {'href': 'https://api.spotify.com/v...  24upABZ8A0sAepfu91sEYr
# 4   {'tracks': {'href': 'https://api.spotify.com/v...  4gOgQTv9RYYFZ1uQNnlk3q
# ..                                                ...                     ...
# 64  {'tracks': {'href': 'https://api.spotify.com/v...  2z4U9d5OAA4YLNXoCgioxo
# 65  {'tracks': {'href': 'https://api.spotify.com/v...  1UuZhGTon3gzXQAJzNa2A4
# 66  {'tracks': {'href': 'https://api.spotify.com/v...  2gTdDMpNxIRFSiu7HutMCg
# 67  {'tracks': {'href': 'https://api.spotify.com/v...  5YLHLxoZsodDWjqSgjhBf3
# 68  {'tracks': {'href': 'https://api.spotify.com/v...  4fzsfWzRhPawzqhX8Qt9F3
#
#    sp_duration_ms sp_popularity sp_release_date sp_explicit  ... sp_key  \
# 0          163636            88      2019-10-10        True  ...      6
# 1          237893            88      2019-11-07        True  ...     11
# 2          170746            82      2019-12-06       False  ...      8
# 3          390638            70      2017-03-03       False  ...      7
# 4           83940            72      2019-03-29        True  ...     10
# ..            ...           ...             ...         ...  ...    ...
# 64         220706            74      2011-03-08       False  ...      6
# 65         273293            55      2015-03-23       False  ...      4
# 66         169397            81      2019-07-05        True  ...      7
# 67         167552            76      2018-04-12       False  ...      9
# 68         311866            80      2007-09-11        True  ...     10
#
#    sp_loudness sp_mode sp_speechiness sp_acousticness sp_instrumentalness  \
# 0       -5.616       0          0.148          0.0522                   0
# 1       -4.577       0          0.158           0.256            3.57e-06
# 2       -6.024       1         0.0296           0.018            1.29e-05
# 3      -10.002       1         0.0345           0.288               0.856
# 4       -8.719       1          0.344          0.0635             0.00932
# ..         ...     ...            ...             ...                 ...
# 64      -3.689       0         0.0548         0.00472              0.0127
# 65      -6.207       0         0.0392          0.0531                   0
# 66      -4.718       1         0.0379          0.0257                   0
# 67      -5.513       0          0.072           0.465            1.12e-06
# 68      -7.858       0          0.153         0.00564                   0
#
#    sp_liveness sp_valence sp_tempo sp_time_signature
# 0         0.46      0.457  116.735                 5
# 1       0.0904      0.786  110.962                 4
# 2       0.0887      0.383  105.046                 4
# 3        0.102     0.0584  117.986                 4
# 4        0.118      0.175  159.947                 4
# ..         ...        ...      ...               ...
# 64        0.14      0.877  149.976                 4
# 65       0.152      0.263   170.18                 4
# 66       0.313      0.277  119.921                 4
# 67      0.0338      0.902  195.918                 4
# 68       0.408       0.49  103.992                 4
#
# [66 rows x 22 columns]

# %% [markdown]
# ### Songs - Chartmetric

# %%
# Check the dataframe
df_cmc_tracks.head()
# Out:
#        song                      artists              artists_list  \
# 0   Roxanne               Arizona Zervas          [Arizona Zervas]
# 1    Say So                     Doja Cat                [Doja Cat]
# 2  My Oh My  Camila Cabello feat. DaBaby  [Camila Cabello, DaBaby]
# 3      Moon              Kid Francescoli         [Kid Francescoli]
# 4      Vibe               Cookiee Kawaii          [Cookiee Kawaii]
#
#    number_artists                   sp_id  \
# 0               1  696DnlkuDOXcMAnKlTgXXK
# 1               1  3Dv1eDb0MEgF93GpLXlucZ
# 2               2  3yOlyBJuViE2YSGn3nVE1K
# 3               1  24upABZ8A0sAepfu91sEYr
# 4               1  4gOgQTv9RYYFZ1uQNnlk3q
#
#                                       cmc_song_seach    cmc_id  \
# 0  {'obj': {'tracks': [{'id': 27228348, 'name': '...  27228348
# 1  {'obj': {'tracks': [{'id': 26951096, 'name': '...  26951096
# 2  {'obj': {'tracks': [{'id': 27597895, 'name': '...  27597895
# 3  {'obj': {'tracks': [{'id': 12263271, 'name': '...  12263271
# 4  {'obj': {'tracks': [{'id': 25138356, 'name': '...  25138356
#
#                                   cmc_track_metadata
# 0  {'obj': {'id': 27228348, 'name': 'ROXANNE', 'i...
# 1  {'obj': {'id': 26951096, 'name': 'Say So', 'is...
# 2  {'obj': {'id': 27597895, 'name': 'My Oh My', '...
# 3  {'obj': {'id': 12263271, 'name': 'Moon', 'isrc...
# 4  {'obj': {'id': 25138356, 'name': 'Vibe', 'isrc...

# %%
# Filter only the songs that were found in Spotify
df_cmc_tracks_found = df_cmc_tracks[df_cmc_tracks.sp_id != 'not-found']
df_cmc_tracks_found
# Out:
#                 song                                         artists  \
# 0            Roxanne                                  Arizona Zervas
# 1             Say So                                        Doja Cat
# 2           My Oh My                     Camila Cabello feat. DaBaby
# 3               Moon                                 Kid Francescoli
# 4               Vibe                                  Cookiee Kawaii
# ..               ...                                             ...
# 64     What the Hell                                   Avril Lavigne
# 65   Towards the Sun                                         Rihanna
# 66  I Think I'm OKAY  Machine Gun Kelly, YUNGBLUD, and Travis Barker
# 67            Myself                                           Bazzi
# 68          Stronger                                      Kanye West
#
#                                     artists_list  number_artists  \
# 0                               [Arizona Zervas]               1
# 1                                     [Doja Cat]               1
# 2                       [Camila Cabello, DaBaby]               2
# 3                              [Kid Francescoli]               1
# 4                               [Cookiee Kawaii]               1
# ..                                           ...             ...
# 64                               [Avril Lavigne]               1
# 65                                     [Rihanna]               1
# 66  [Machine Gun Kelly, YUNGBLUD, Travis Barker]               3
# 67                                       [Bazzi]               1
# 68                                  [Kanye West]               1
#
#                      sp_id                                     cmc_song_seach  \
# 0   696DnlkuDOXcMAnKlTgXXK  {'obj': {'tracks': [{'id': 27228348, 'name': '...
# 1   3Dv1eDb0MEgF93GpLXlucZ  {'obj': {'tracks': [{'id': 26951096, 'name': '...
# 2   3yOlyBJuViE2YSGn3nVE1K  {'obj': {'tracks': [{'id': 27597895, 'name': '...
# 3   24upABZ8A0sAepfu91sEYr  {'obj': {'tracks': [{'id': 12263271, 'name': '...
# 4   4gOgQTv9RYYFZ1uQNnlk3q  {'obj': {'tracks': [{'id': 25138356, 'name': '...
# ..                     ...                                                ...
# 64  2z4U9d5OAA4YLNXoCgioxo  {'obj': {'tracks': [{'id': 15674355, 'name': '...
# 65  1UuZhGTon3gzXQAJzNa2A4  {'obj': {'tracks': [{'id': 13795060, 'name': '...
# 66  2gTdDMpNxIRFSiu7HutMCg  {'obj': {'tracks': [{'id': 23903635, 'name': "...
# 67  5YLHLxoZsodDWjqSgjhBf3  {'obj': {'tracks': [{'id': 19040153, 'name': '...
# 68  4fzsfWzRhPawzqhX8Qt9F3  {'obj': {'tracks': [{'id': 15906456, 'name': '...
#
#       cmc_id                                 cmc_track_metadata
# 0   27228348  {'obj': {'id': 27228348, 'name': 'ROXANNE', 'i...
# 1   26951096  {'obj': {'id': 26951096, 'name': 'Say So', 'is...
# 2   27597895  {'obj': {'id': 27597895, 'name': 'My Oh My', '...
# 3   12263271  {'obj': {'id': 12263271, 'name': 'Moon', 'isrc...
# 4   25138356  {'obj': {'id': 25138356, 'name': 'Vibe', 'isrc...
# ..       ...                                                ...
# 64  15674355  {'obj': {'id': 15674355, 'name': 'What The Hel...
# 65  13795060  {'obj': {'id': 13795060, 'name': 'Towards The ...
# 66  23903635  {'obj': {'id': 23903635, 'name': 'I Think I'm ...
# 67  19040153  {'obj': {'id': 19040153, 'name': 'Myself', 'is...
# 68  15906456  {'obj': {'id': 15906456, 'name': 'Stronger', '...
#
# [66 rows x 8 columns]

# %%
# Add Chartmetric information to the dataframe

# Duration ms
df_cmc_tracks_found['cmc_track_duration_ms'] = [each_row['obj']['duration_ms'] 
                                                if type(each_row) == dict 
                                                else 'not-found' 
                                                for each_row in df_cmc_tracks_found.cmc_track_metadata]

# Tags
df_cmc_tracks_found['cmc_track_tags'] = [each_row['obj']['tags'] 
                                         if type(each_row) == dict 
                                         else 'not-found' 
                                         for each_row in df_cmc_tracks_found.cmc_track_metadata]

# Release date
df_cmc_tracks_found['cmc_track_release_date'] = [each_row['obj']['release_date'] 
                                                 if type(each_row) == dict 
                                                 else 'not-found' 
                                                 for each_row in df_cmc_tracks_found.cmc_track_metadata]

# Chartmetric features
## Key
df_cmc_tracks_found['cmc_track_feat_key'] = [each_row['obj']['cm_audio_features']['key'] 
                                             if type(each_row['obj']['cm_audio_features']) == dict 
                                             else 'not-value' 
                                             for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Mode
df_cmc_tracks_found['cmc_track_feat_mode'] = [each_row['obj']['cm_audio_features']['mode'] 
                                              if type(each_row['obj']['cm_audio_features']) == dict 
                                              else 'not-value' 
                                              for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Danceability %
df_cmc_tracks_found['cmc_track_feat_danceability'] = [each_row['obj']['cm_audio_features']['danceability'] 
                                                      if type(each_row['obj']['cm_audio_features']) == dict 
                                                      else 'not-value' 
                                                      for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Energy %
df_cmc_tracks_found['cmc_track_feat_energy'] = [each_row['obj']['cm_audio_features']['energy'] 
                                                if type(each_row['obj']['cm_audio_features']) == dict 
                                                else 'not-value' 
                                                for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Speechiness
df_cmc_tracks_found['cmc_track_feat_speechiness'] = [each_row['obj']['cm_audio_features']['speechiness'] 
                                                     if type(each_row['obj']['cm_audio_features']) == dict 
                                                     else 'not-value' 
                                                     for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Acousticness %
df_cmc_tracks_found['cmc_track_feat_acousticness'] = [each_row['obj']['cm_audio_features']['acousticness'] 
                                                      if type(each_row['obj']['cm_audio_features']) == dict 
                                                      else 'not-value' 
                                                      for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Instrumentalness
df_cmc_tracks_found['cmc_track_feat_instrumentalness'] = [each_row['obj']['cm_audio_features']['instrumentalness'] 
                                                          if type(each_row['obj']['cm_audio_features']) == dict 
                                                          else 'not-value' 
                                                          for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Liveness %
df_cmc_tracks_found['cmc_track_feat_liveness'] = [each_row['obj']['cm_audio_features']['liveness'] 
                                                  if type(each_row['obj']['cm_audio_features']) == dict 
                                                  else 'not-value' 
                                                  for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Valence %
df_cmc_tracks_found['cmc_track_feat_valence'] = [each_row['obj']['cm_audio_features']['valence'] 
                                                 if type(each_row['obj']['cm_audio_features']) == dict 
                                                 else 'not-value' 
                                                 for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Tempo
df_cmc_tracks_found['cmc_track_feat_tempo'] = [each_row['obj']['cm_audio_features']['tempo'] 
                                               if type(each_row['obj']['cm_audio_features']) == dict 
                                               else 'not-value' 
                                               for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Loudness
df_cmc_tracks_found['cmc_track_feat_loudness'] = [each_row['obj']['cm_audio_features']['loudness'] 
                                                  if type(each_row['obj']['cm_audio_features']) == dict 
                                                  else 'not-value' 
                                                  for each_row in df_cmc_tracks_found.cmc_track_metadata]

# Chartmetric statistics
## Spotify Popularity
df_cmc_tracks_found['cmc_track_stat_sp_pop'] = [each_row['obj']['cm_statistics']['sp_popularity'] 
                                                if type(each_row['obj']['cm_audio_features']) == dict 
                                                else 'not-value' 
                                                for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Number of TikTok posts
df_cmc_tracks_found['cmc_track_stat_tiktok_counts'] = [each_row['obj']['cm_statistics']['tiktok_counts'] 
                                                       if type(each_row['obj']['cm_audio_features']) == dict 
                                                       else 'not-value' 
                                                       for each_row in df_cmc_tracks_found.cmc_track_metadata]

## Youtube views
df_cmc_tracks_found['cmc_track_stat_youtube_views'] = [each_row['obj']['cm_statistics']['youtube_views'] 
                                                       if type(each_row['obj']['cm_audio_features']) == dict 
                                                       else 'not-value' 
                                                       for each_row in df_cmc_tracks_found.cmc_track_metadata]
# Out:
# <ipython-input-124-5fc5ab9948bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_duration_ms'] = [each_row['obj']['duration_ms']
# <ipython-input-124-5fc5ab9948bf>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_tags'] = [each_row['obj']['tags']
# <ipython-input-124-5fc5ab9948bf>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_release_date'] = [each_row['obj']['release_date']
# <ipython-input-124-5fc5ab9948bf>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_key'] = [each_row['obj']['cm_audio_features']['key']
# <ipython-input-124-5fc5ab9948bf>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_mode'] = [each_row['obj']['cm_audio_features']['mode']
# <ipython-input-124-5fc5ab9948bf>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_danceability'] = [each_row['obj']['cm_audio_features']['danceability']
# <ipython-input-124-5fc5ab9948bf>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_energy'] = [each_row['obj']['cm_audio_features']['energy']
# <ipython-input-124-5fc5ab9948bf>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_speechiness'] = [each_row['obj']['cm_audio_features']['speechiness']
# <ipython-input-124-5fc5ab9948bf>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_acousticness'] = [each_row['obj']['cm_audio_features']['acousticness']
# <ipython-input-124-5fc5ab9948bf>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_instrumentalness'] = [each_row['obj']['cm_audio_features']['instrumentalness']
# <ipython-input-124-5fc5ab9948bf>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_liveness'] = [each_row['obj']['cm_audio_features']['liveness']
# <ipython-input-124-5fc5ab9948bf>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_valence'] = [each_row['obj']['cm_audio_features']['valence']
# <ipython-input-124-5fc5ab9948bf>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_tempo'] = [each_row['obj']['cm_audio_features']['tempo']
# <ipython-input-124-5fc5ab9948bf>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_feat_loudness'] = [each_row['obj']['cm_audio_features']['loudness']
# <ipython-input-124-5fc5ab9948bf>:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_stat_sp_pop'] = [each_row['obj']['cm_statistics']['sp_popularity']
# <ipython-input-124-5fc5ab9948bf>:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_stat_tiktok_counts'] = [each_row['obj']['cm_statistics']['tiktok_counts']
# <ipython-input-124-5fc5ab9948bf>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cmc_tracks_found['cmc_track_stat_youtube_views'] = [each_row['obj']['cm_statistics']['youtube_views']

# %%
# Check the result
df_cmc_tracks_found.head()
# Out:
#        song                      artists              artists_list  \
# 0   Roxanne               Arizona Zervas          [Arizona Zervas]
# 1    Say So                     Doja Cat                [Doja Cat]
# 2  My Oh My  Camila Cabello feat. DaBaby  [Camila Cabello, DaBaby]
# 3      Moon              Kid Francescoli         [Kid Francescoli]
# 4      Vibe               Cookiee Kawaii          [Cookiee Kawaii]
#
#    number_artists                   sp_id  \
# 0               1  696DnlkuDOXcMAnKlTgXXK
# 1               1  3Dv1eDb0MEgF93GpLXlucZ
# 2               2  3yOlyBJuViE2YSGn3nVE1K
# 3               1  24upABZ8A0sAepfu91sEYr
# 4               1  4gOgQTv9RYYFZ1uQNnlk3q
#
#                                       cmc_song_seach    cmc_id  \
# 0  {'obj': {'tracks': [{'id': 27228348, 'name': '...  27228348
# 1  {'obj': {'tracks': [{'id': 26951096, 'name': '...  26951096
# 2  {'obj': {'tracks': [{'id': 27597895, 'name': '...  27597895
# 3  {'obj': {'tracks': [{'id': 12263271, 'name': '...  12263271
# 4  {'obj': {'tracks': [{'id': 25138356, 'name': '...  25138356
#
#                                   cmc_track_metadata  cmc_track_duration_ms  \
# 0  {'obj': {'id': 27228348, 'name': 'ROXANNE', 'i...                 163636
# 1  {'obj': {'id': 26951096, 'name': 'Say So', 'is...                 237893
# 2  {'obj': {'id': 27597895, 'name': 'My Oh My', '...                 170746
# 3  {'obj': {'id': 12263271, 'name': 'Moon', 'isrc...                 390638
# 4  {'obj': {'id': 25138356, 'name': 'Vibe', 'isrc...                  84008
#
#                            cmc_track_tags  ... cmc_track_feat_speechiness  \
# 0  Hip-Hop/Rap,Music,Pop,Música,Pop,Musik  ...                      0.148
# 1             Dance,Musica,R&B/Soul,Music  ...                      0.158
# 2                               Pop,Music  ...                     0.0296
# 3                               Pop,Music  ...                     0.0345
# 4                    Dance,Music,R&B/Soul  ...                      0.384
#
#   cmc_track_feat_acousticness cmc_track_feat_instrumentalness  \
# 0                      0.0522                               0
# 1                       0.256                        3.57e-06
# 2                       0.018                        1.29e-05
# 3                       0.291                           0.863
# 4                      0.0676                         0.00951
#
#   cmc_track_feat_liveness cmc_track_feat_valence cmc_track_feat_tempo  \
# 0                    0.46                  0.457              116.735
# 1                  0.0904                  0.786              110.962
# 2                  0.0887                  0.383              105.046
# 3                   0.101                 0.0578              117.984
# 4                   0.117                  0.169              159.995
#
#   cmc_track_feat_loudness cmc_track_stat_sp_pop cmc_track_stat_tiktok_counts  \
# 0                  -5.616                    88                      2300000
# 1                  -4.577                    89                     19300000
# 2                  -6.024                  None                      1900000
# 3                 -10.002                    20                       759300
# 4                   -8.74                    21                      1900000
#
#   cmc_track_stat_youtube_views
# 0                     96679674
# 1                    198853609
# 2                     49709340
# 3                         None
# 4                         None
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Merge the two dataframes

# %%
# Merge the dataframes
df_tracks_final_raw = pd.merge(left=df_tracks_sp_found, right=df_cmc_tracks_found, on='song')

# Check the result
df_tracks_final_raw
# Out:
#                 song                                       artists_x  \
# 0            Roxanne                                  Arizona Zervas
# 1             Say So                                        Doja Cat
# 2           My Oh My                     Camila Cabello feat. DaBaby
# 3               Moon                                 Kid Francescoli
# 4               Vibe                                  Cookiee Kawaii
# ..               ...                                             ...
# 61     What the Hell                                   Avril Lavigne
# 62   Towards the Sun                                         Rihanna
# 63  I Think I'm OKAY  Machine Gun Kelly, YUNGBLUD, and Travis Barker
# 64            Myself                                           Bazzi
# 65          Stronger                                      Kanye West
#
#                                   artists_list_x  number_artists_x  \
# 0                               [Arizona Zervas]                 1
# 1                                     [Doja Cat]                 1
# 2                       [Camila Cabello, DaBaby]                 2
# 3                              [Kid Francescoli]                 1
# 4                               [Cookiee Kawaii]                 1
# ..                                           ...               ...
# 61                               [Avril Lavigne]                 1
# 62                                     [Rihanna]                 1
# 63  [Machine Gun Kelly, YUNGBLUD, Travis Barker]                 3
# 64                                       [Bazzi]                 1
# 65                                  [Kanye West]                 1
#
#                                        spotify_search                 sp_id_x  \
# 0   {'tracks': {'href': 'https://api.spotify.com/v...  696DnlkuDOXcMAnKlTgXXK
# 1   {'tracks': {'href': 'https://api.spotify.com/v...  3Dv1eDb0MEgF93GpLXlucZ
# 2   {'tracks': {'href': 'https://api.spotify.com/v...  3yOlyBJuViE2YSGn3nVE1K
# 3   {'tracks': {'href': 'https://api.spotify.com/v...  24upABZ8A0sAepfu91sEYr
# 4   {'tracks': {'href': 'https://api.spotify.com/v...  4gOgQTv9RYYFZ1uQNnlk3q
# ..                                                ...                     ...
# 61  {'tracks': {'href': 'https://api.spotify.com/v...  2z4U9d5OAA4YLNXoCgioxo
# 62  {'tracks': {'href': 'https://api.spotify.com/v...  1UuZhGTon3gzXQAJzNa2A4
# 63  {'tracks': {'href': 'https://api.spotify.com/v...  2gTdDMpNxIRFSiu7HutMCg
# 64  {'tracks': {'href': 'https://api.spotify.com/v...  5YLHLxoZsodDWjqSgjhBf3
# 65  {'tracks': {'href': 'https://api.spotify.com/v...  4fzsfWzRhPawzqhX8Qt9F3
#
#    sp_duration_ms sp_popularity sp_release_date sp_explicit  ...  \
# 0          163636            88      2019-10-10        True  ...
# 1          237893            88      2019-11-07        True  ...
# 2          170746            82      2019-12-06       False  ...
# 3          390638            70      2017-03-03       False  ...
# 4           83940            72      2019-03-29        True  ...
# ..            ...           ...             ...         ...  ...
# 61         220706            74      2011-03-08       False  ...
# 62         273293            55      2015-03-23       False  ...
# 63         169397            81      2019-07-05        True  ...
# 64         167552            76      2018-04-12       False  ...
# 65         311866            80      2007-09-11        True  ...
#
#    cmc_track_feat_speechiness cmc_track_feat_acousticness  \
# 0                       0.148                      0.0522
# 1                       0.158                       0.256
# 2                      0.0296                       0.018
# 3                      0.0345                       0.291
# 4                       0.384                      0.0676
# ..                        ...                         ...
# 61                     0.0584                     0.00483
# 62                     0.0408                      0.0559
# 63                      0.036                      0.0327
# 64                      0.072                       0.465
# 65                        0.2                     0.00754
#
#    cmc_track_feat_instrumentalness cmc_track_feat_liveness  \
# 0                                0                    0.46
# 1                         3.57e-06                  0.0904
# 2                         1.29e-05                  0.0887
# 3                            0.863                   0.101
# 4                          0.00951                   0.117
# ..                             ...                     ...
# 61                         0.00956                   0.163
# 62                               0                   0.156
# 63                               0                     0.3
# 64                        1.12e-06                  0.0338
# 65                               0                   0.631
#
#    cmc_track_feat_valence cmc_track_feat_tempo cmc_track_feat_loudness  \
# 0                   0.457              116.735                  -5.616
# 1                   0.786              110.962                  -4.577
# 2                   0.383              105.046                  -6.024
# 3                  0.0578              117.984                 -10.002
# 4                   0.169              159.995                   -8.74
# ..                    ...                  ...                     ...
# 61                  0.885              150.081                  -5.162
# 62                  0.241              170.211                  -6.143
# 63                   0.24               119.94                  -4.691
# 64                  0.902              195.918                  -5.513
# 65                   0.52              104.063                  -9.476
#
#    cmc_track_stat_sp_pop cmc_track_stat_tiktok_counts  \
# 0                     88                      2300000
# 1                     89                     19300000
# 2                   None                      1900000
# 3                     20                       759300
# 4                     21                      1900000
# ..                   ...                          ...
# 61                    74                      1600000
# 62                    59                         None
# 63                    20                       254900
# 64                    77                      3700000
# 65                    80                        16200
#
#    cmc_track_stat_youtube_views
# 0                      96679674
# 1                     198853609
# 2                      49709340
# 3                          None
# 4                          None
# ..                          ...
# 61                    337047363
# 62                       912388
# 63                     50808170
# 64                     43521205
# 65                       354541
#
# [66 rows x 46 columns]

# %%
# Remove unwanted columns
df_tracks_final = df_tracks_final_raw.drop(columns=['spotify_search', 'cmc_song_seach', 'cmc_track_metadata'])

# Check the result
df_tracks_final
# Out:
#                 song                                       artists_x  \
# 0            Roxanne                                  Arizona Zervas
# 1             Say So                                        Doja Cat
# 2           My Oh My                     Camila Cabello feat. DaBaby
# 3               Moon                                 Kid Francescoli
# 4               Vibe                                  Cookiee Kawaii
# ..               ...                                             ...
# 61     What the Hell                                   Avril Lavigne
# 62   Towards the Sun                                         Rihanna
# 63  I Think I'm OKAY  Machine Gun Kelly, YUNGBLUD, and Travis Barker
# 64            Myself                                           Bazzi
# 65          Stronger                                      Kanye West
#
#                                   artists_list_x  number_artists_x  \
# 0                               [Arizona Zervas]                 1
# 1                                     [Doja Cat]                 1
# 2                       [Camila Cabello, DaBaby]                 2
# 3                              [Kid Francescoli]                 1
# 4                               [Cookiee Kawaii]                 1
# ..                                           ...               ...
# 61                               [Avril Lavigne]                 1
# 62                                     [Rihanna]                 1
# 63  [Machine Gun Kelly, YUNGBLUD, Travis Barker]                 3
# 64                                       [Bazzi]                 1
# 65                                  [Kanye West]                 1
#
#                    sp_id_x sp_duration_ms sp_popularity sp_release_date  \
# 0   696DnlkuDOXcMAnKlTgXXK         163636            88      2019-10-10
# 1   3Dv1eDb0MEgF93GpLXlucZ         237893            88      2019-11-07
# 2   3yOlyBJuViE2YSGn3nVE1K         170746            82      2019-12-06
# 3   24upABZ8A0sAepfu91sEYr         390638            70      2017-03-03
# 4   4gOgQTv9RYYFZ1uQNnlk3q          83940            72      2019-03-29
# ..                     ...            ...           ...             ...
# 61  2z4U9d5OAA4YLNXoCgioxo         220706            74      2011-03-08
# 62  1UuZhGTon3gzXQAJzNa2A4         273293            55      2015-03-23
# 63  2gTdDMpNxIRFSiu7HutMCg         169397            81      2019-07-05
# 64  5YLHLxoZsodDWjqSgjhBf3         167552            76      2018-04-12
# 65  4fzsfWzRhPawzqhX8Qt9F3         311866            80      2007-09-11
#
#    sp_explicit sp_danceability  ... cmc_track_feat_speechiness  \
# 0         True           0.621  ...                      0.148
# 1         True           0.787  ...                      0.158
# 2        False           0.724  ...                     0.0296
# 3        False           0.662  ...                     0.0345
# 4         True           0.754  ...                      0.384
# ..         ...             ...  ...                        ...
# 61       False           0.578  ...                     0.0584
# 62       False           0.261  ...                     0.0408
# 63        True           0.628  ...                      0.036
# 64       False           0.745  ...                      0.072
# 65        True           0.617  ...                        0.2
#
#    cmc_track_feat_acousticness cmc_track_feat_instrumentalness  \
# 0                       0.0522                               0
# 1                        0.256                        3.57e-06
# 2                        0.018                        1.29e-05
# 3                        0.291                           0.863
# 4                       0.0676                         0.00951
# ..                         ...                             ...
# 61                     0.00483                         0.00956
# 62                      0.0559                               0
# 63                      0.0327                               0
# 64                       0.465                        1.12e-06
# 65                     0.00754                               0
#
#    cmc_track_feat_liveness cmc_track_feat_valence cmc_track_feat_tempo  \
# 0                     0.46                  0.457              116.735
# 1                   0.0904                  0.786              110.962
# 2                   0.0887                  0.383              105.046
# 3                    0.101                 0.0578              117.984
# 4                    0.117                  0.169              159.995
# ..                     ...                    ...                  ...
# 61                   0.163                  0.885              150.081
# 62                   0.156                  0.241              170.211
# 63                     0.3                   0.24               119.94
# 64                  0.0338                  0.902              195.918
# 65                   0.631                   0.52              104.063
#
#    cmc_track_feat_loudness cmc_track_stat_sp_pop cmc_track_stat_tiktok_counts  \
# 0                   -5.616                    88                      2300000
# 1                   -4.577                    89                     19300000
# 2                   -6.024                  None                      1900000
# 3                  -10.002                    20                       759300
# 4                    -8.74                    21                      1900000
# ..                     ...                   ...                          ...
# 61                  -5.162                    74                      1600000
# 62                  -6.143                    59                         None
# 63                  -4.691                    20                       254900
# 64                  -5.513                    77                      3700000
# 65                  -9.476                    80                        16200
#
#    cmc_track_stat_youtube_views
# 0                      96679674
# 1                     198853609
# 2                      49709340
# 3                          None
# 4                          None
# ..                          ...
# 61                    337047363
# 62                       912388
# 63                     50808170
# 64                     43521205
# 65                       354541
#
# [66 rows x 43 columns]

# %% [markdown]
# ### Export the dataframe

# %%
# Export the dataframe
df_tracks_final_raw.to_csv('01-tracks_data_final_raw.csv', index=False)
df_tracks_final.to_csv('01-tracks_data_final.csv', index=False)

# %% [markdown]
# ## Artists

# %% [markdown]
# ### Artists - Spotify

# %%
# Check the dataframe
df_artists
# Out:
#                artist                   sp_id  \
# 0      Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1            Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2      Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3              DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4     Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
# ..                ...                     ...
# 83  Machine Gun Kelly  6TIYQ3jFPwQSRmorSezPxX
# 84           YUNGBLUD  6Ad91Jof8Niiw0lGLLi3NW
# 85      Travis Barker  4exLIFE8sISLr28sqG1qNX
# 86              Bazzi  4GvEc3ANtPPjt1ZJllr5Zl
# 87         Kanye West  5K4W6rqBFWDnAN6FQUkS6x
#
#                                        spotify_artist  \
# 0   {'external_urls': {'spotify': 'https://open.sp...
# 1   {'external_urls': {'spotify': 'https://open.sp...
# 2   {'external_urls': {'spotify': 'https://open.sp...
# 3   {'external_urls': {'spotify': 'https://open.sp...
# 4   {'external_urls': {'spotify': 'https://open.sp...
# ..                                                ...
# 83  {'external_urls': {'spotify': 'https://open.sp...
# 84  {'external_urls': {'spotify': 'https://open.sp...
# 85  {'external_urls': {'spotify': 'https://open.sp...
# 86  {'external_urls': {'spotify': 'https://open.sp...
# 87  {'external_urls': {'spotify': 'https://open.sp...
#
#                                             sp_genres  sp_popularity  \
# 0                    [pop rap, rap, rhode island rap]             80
# 1                                     [la indie, pop]             88
# 2                     [dance pop, pop, post-teen pop]             87
# 3                       [north carolina hip hop, rap]             95
# 4   [electronica, french indie pop, french indietr...             61
# ..                                                ...            ...
# 83                       [ohio hip hop, pop rap, rap]             86
# 84  [british indie rock, modern alternative rock, ...             78
# 85                                         [rap rock]             77
# 86                               [pop, post-teen pop]             83
# 87                                 [chicago rap, rap]             91
#
#     sp_followers
# 0         486779
# 1        3445699
# 2       17989469
# 3        4326193
# 4          82296
# ..           ...
# 83       2454191
# 84       1085134
# 85        252326
# 86       3671755
# 87      12428005
#
# [88 rows x 6 columns]

# %% [markdown]
# ### Artists - Chartmetric

# %%
# Import the dataset
cmc_art_teste = pd.read_csv('cmc_artists_info.csv')

# Check the result
cmc_art_teste
# Out:
#                artist                   sp_id  \
# 0      Arizona Zervas  0vRvGUQVUjytro0xpb26bs
# 1            Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 2      Camila Cabello  4nDoRrQiYLoBzwC5BhVJzF
# 3              DaBaby  4r63FhuTkUYltbVAg5TQnk
# 4     Kid Francescoli  2G7QgTep5IsJHGHm1hXygD
# ..                ...                     ...
# 83  Machine Gun Kelly  6TIYQ3jFPwQSRmorSezPxX
# 84           YUNGBLUD  6Ad91Jof8Niiw0lGLLi3NW
# 85      Travis Barker  4exLIFE8sISLr28sqG1qNX
# 86              Bazzi  4GvEc3ANtPPjt1ZJllr5Zl
# 87         Kanye West  5K4W6rqBFWDnAN6FQUkS6x
#
#                                             sp_genres  sp_popularity  \
# 0              ['pop rap', 'rap', 'rhode island rap']             80
# 1                                 ['la indie', 'pop']             88
# 2               ['dance pop', 'pop', 'post-teen pop']             87
# 3                   ['north carolina hip hop', 'rap']             95
# 4   ['electronica', 'french indie pop', 'french in...             61
# ..                                                ...            ...
# 83                 ['ohio hip hop', 'pop rap', 'rap']             86
# 84  ['british indie rock', 'modern alternative roc...             78
# 85                                       ['rap rock']             77
# 86                           ['pop', 'post-teen pop']             83
# 87                             ['chicago rap', 'rap']             91
#
#     sp_followers                                         cmc_search  cmc_id  \
# 0         486779  {'obj': {'artists': [{'id': 64150, 'name': 'Ar...   64150
# 1        3445699  {'obj': {'artists': [{'id': 217671, 'name': 'D...  217671
# 2       17989469  {'obj': {'artists': [{'id': 454302, 'name': 'C...  454302
# 3        4326193  {'obj': {'artists': [{'id': 398544, 'name': 'D...  398544
# 4          82296  {'obj': {'artists': [{'id': 147365, 'name': 'K...  147365
# ..           ...                                                ...     ...
# 83       2454191  {'obj': {'artists': [{'id': 3991, 'name': 'Mac...    3991
# 84       1085134  {'obj': {'artists': [{'id': 558951, 'name': 'Y...  558951
# 85        252326  {'obj': {'artists': [{'id': 216839, 'name': 'T...  216839
# 86       3671755  {'obj': {'artists': [{'id': 213807, 'name': 'B...  213807
# 87      12428005  {'obj': {'artists': [{'id': 1845, 'name': 'Kan...    1845
#
#                                      cmc_art_metadata  \
# 0   {'obj': {'id': 64150, 'name': 'Arizona Zervas'...
# 1   {'obj': {'id': 217671, 'name': 'Doja Cat', 'cr...
# 2   {'obj': {'id': 454302, 'name': 'Camila Cabello...
# 3   {'obj': {'id': 398544, 'name': 'DaBaby', 'crea...
# 4   {'obj': {'id': 147365, 'name': 'Kid Francescol...
# ..                                                ...
# 83  {'obj': {'id': 3991, 'name': 'Machine Gun Kell...
# 84  {'obj': {'id': 558951, 'name': 'YUNGBLUD', 'cr...
# 85  {'obj': {'id': 216839, 'name': 'Travis Barker'...
# 86  {'obj': {'id': 213807, 'name': 'Bazzi', 'creat...
# 87  {'obj': {'id': 1845, 'name': 'Kanye West', 'cr...
#
#                                       cmc_art_sp_city  \
# 0   {'obj': {'Atlanta': [{'timestp': '2020-03-21T0...
# 1   {'obj': {'Atlanta': [{'timestp': '2020-03-21T0...
# 2   {'obj': {'Brisbane': [{'timestp': '2020-03-21T...
# 3   {'obj': {'Atlanta': [{'timestp': '2020-03-21T0...
# 4   {'obj': {'Berlin': [{'timestp': '2020-03-21T00...
# ..                                                ...
# 83  {'obj': {'Atlanta': [{'timestp': '2020-03-21T0...
# 84  {'obj': {'Atlanta': [{'timestp': '2020-03-21T0...
# 85  {'obj': {'Atlanta': [{'timestp': '2020-03-21T0...
# 86  {'obj': {'Atlanta': [{'timestp': '2020-03-21T0...
# 87  {'obj': {'Atlanta': [{'timestp': '2020-03-21T0...
#
#                               cmc_art_tiktok_audience
# 0   {'obj': {'top_countries': [{'name': 'United St...
# 1   {'obj': {'top_countries': [{'name': 'United St...
# 2   {'obj': {'top_countries': [{'name': 'United St...
# 3   {'obj': {'top_countries': [], 'audience_gender...
# 4   {'obj': {'top_countries': [], 'audience_gender...
# ..                                                ...
# 83  {'obj': {'top_countries': [{'name': 'United St...
# 84  {'obj': {'top_countries': [{'name': 'United St...
# 85  {'obj': {'top_countries': [], 'audience_gender...
# 86  {'obj': {'top_countries': [{'name': 'United St...
# 87  {'obj': {'top_countries': [], 'audience_gender...
#
# [88 rows x 10 columns]

# %%
# Convert the strings to list or dictionaries
cmc_art_teste.sp_genres = cmc_art_teste.sp_genres.apply(literal_eval)
cmc_art_teste.cmc_search = cmc_art_teste.cmc_search.apply(literal_eval)
cmc_art_teste.cmc_art_metadata = cmc_art_teste.cmc_art_metadata.apply(literal_eval)
cmc_art_teste.cmc_art_sp_city = cmc_art_teste.cmc_art_sp_city.apply(literal_eval)
cmc_art_teste.cmc_art_tiktok_audience = cmc_art_teste.cmc_art_tiktok_audience.apply(literal_eval)

# %%
# Check the results
print(f'sp_genres: {type(cmc_art_teste.sp_genres[0])}')
print(f'cmc_search: {type(cmc_art_teste.cmc_search[0])}')
print(f'cmc_art_metadata: {type(cmc_art_teste.cmc_art_metadata[0])}')
print(f'cmc_art_sp_city: {type(cmc_art_teste.cmc_art_sp_city[0])}')
print(f'cmc_art_tiktok_audience: {type(cmc_art_teste.cmc_art_tiktok_audience[0])}')
# Out:
# sp_genres: <class 'list'>
# cmc_search: <class 'dict'>
# cmc_art_metadata: <class 'dict'>
# cmc_art_sp_city: <class 'dict'>
# cmc_art_tiktok_audience: <class 'dict'>

# %%
cmc_art_teste.cmc_search[0]['obj']['artists'][0]
# Out:
# {'id': 64150,
#  'name': 'Arizona Zervas',
#  'image_url': 'https://i.scdn.co/image/d549aadbb8b3a254fdc8e5ac93535a706463dce6',
#  'isni': None,
#  'code2': 'us',
#  'hometown_city': None,
#  'current_city': None,
#  'sp_followers': 485529,
#  'sp_popularity': 80,
#  'sp_monthly_listeners': 15313268,
#  'deezer_fans': 29274,
#  'tags': ['pop', 'pop rap'],
#  'spotify_artist_ids': ['0vRvGUQVUjytro0xpb26bs'],
#  'itunes_artist_ids': [1026196272],
#  'deezer_artist_ids': ['8650540'],
#  'cm_artist_rank': 353,
#  'amazon_artist_ids': ['B013CV8F1E']}

# %%
cmc_art_teste.cmc_art_metadata[0]['obj']
# Out:
# {'id': 64150,
#  'name': 'Arizona Zervas',
#  'created_at': '2016-11-26T00:00:00.000Z',
#  'code2': 'us',
#  'gender': 1,
#  'isni': None,
#  'cm_artist_rank': 366,
#  'cover_url': 'https://i.scdn.co/image/ab67616d0000b273bf30549de1c332630a11133f',
#  'image_url': 'https://i.scdn.co/image/d549aadbb8b3a254fdc8e5ac93535a706463dce6',
#  'hometown_city': None,
#  'current_city': None,
#  'current_city_id': None,
#  'record_label': None,
#  'band_members': None,
#  'press_contact': None,
#  'booking_agent': None,
#  'description': 'Without a label or mainstream presence, hip-hop- and R&B-influenced singer and rapper Arizona Zervas amassed a devoted following that boosted streams of his early singles into the millions, culminating in 2019\'s viral smash single "Roxanne."\r\n\nDespite his name, Zervas was born and raised in Maryland in 1995. Writing since high school, he uploaded his early songs online, building an audience with his freestyles and tracks including his 2016 debut "Don\'t Hit My Line." Blending the styles and deliveries of influences like <a href="spotify:artist:4W9G3Vnt9eXWTo4VeOQkSa">Drake</a>, <a href="spotify:artist:246dkjvS1zLTtiykXe5h60">Post Malone</a>, and <a href="spotify:artist:6oMuImdp5ZcFhWP0ESe6mG">Migos</a>, Zervas alternated melodic choruses and rapped verses, covering topics such as bad relationships, blossoming fame, and youthful hedonism. With each successive song, his streaming numbers increased exponentially over the course of a dozen singles and an EP, 2018\'s Living Facts. In 2019, he made his breakthrough with the help of a viral social media campaign for his song "Roxanne." Released in October, the melodic pop-rap earworm catapulted Zervas into the Top Five on the Billboard Hot 100. Meanwhile, he topped the charts in New Zealand and Belgium and rose into the Top Ten around the globe. He was swiftly signed by <a href="spotify:search:label%3A%22Columbia+Records%22">Columbia Records</a> and returned in 2020 with the songs "24" and "Nightrider." ~ Neil Z. Yeung',
#  'tags': [{'id': 188, 'name': 'pop'}, {'id': 8904, 'name': 'pop rap'}],
#  'cm_statistics': {'sp_followers': 485529,
#   'sp_followers_rank': 3269,
#   'deezer_fans': '29274',
#   'deezer_fans_rank': 7336,
#   'sp_popularity': 80,
#   'sp_popularity_rank': 459,
#   'sp_monthly_listeners': 15313268,
#   'sp_monthly_listeners_rank': 215,
#   'sp_where_people_listen': [{'name': 'Chicago',
#     'code2': 'us',
#     'listeners': 263138},
#    {'name': 'Los Angeles', 'code2': 'us', 'listeners': 184544},
#    {'name': 'Dallas', 'code2': 'us', 'listeners': 176417},
#    {'name': 'Sydney', 'code2': 'au', 'listeners': 165703},
#    {'name': 'Atlanta', 'code2': 'us', 'listeners': 157882}],
#   'ins_followers': 244360,
#   'ins_followers_rank': 11391,
#   'ycs_subscribers': 773000,
#   'ycs_subscribers_rank': 3520,
#   'ycs_views': '210537188',
#   'ycs_views_rank': 3746,
#   'tiktok_followers': 449300,
#   'tiktok_followers_rank': 1447,
#   'tiktok_likes': '1400000',
#   'tiktok_likes_rank': 1906,
#   'cm_artist_rank': 353,
#   'youtube_daily_video_views': '1414489',
#   'youtube_daily_video_views_rank': 660,
#   'youtube_monthly_video_views': '44696550',
#   'youtube_monthly_video_views_rank': 562,
#   'twitch_followers': None,
#   'twitch_followers_rank': 0,
#   'twitch_views': None,
#   'twitch_views_rank': 0,
#   'twitch_monthly_viewer_hours': None,
#   'twitch_monthly_viewer_hours_rank': 0,
#   'twitch_weekly_viewer_hours': None,
#   'twitch_weekly_viewer_hours_rank': 0,
#   'num_sp_editorial_playlists': 355,
#   'num_sp_playlists': 8049,
#   'sp_playlist_total_reach': 57522476,
#   'sp_editorial_playlist_total_reach': 31617575,
#   'num_am_editorial_playlists': 16,
#   'num_am_playlists': 167,
#   'num_de_editorial_playlists': 14,
#   'num_de_playlists': 53,
#   'de_playlist_total_reach': 3078195,
#   'de_editorial_playlist_total_reach': 2706502,
#   'num_az_editorial_playlists': 41,
#   'num_az_playlists': 41,
#   'num_yt_editorial_playlists': 1,
#   'num_yt_playlists': 6,
#   'yt_playlist_total_reach': 167578575,
#   'yt_editorial_playlist_total_reach': 1034137}}

# %%
cmc_a
# Out:
# [{'timestp': '2020-03-21T00:00:00.000Z', 'code2': 'US', 'listeners': 437048},
#  {'timestp': '2020-03-22T00:00:00.000Z', 'code2': 'US', 'listeners': 432350},
#  {'timestp': '2020-03-23T00:00:00.000Z', 'code2': 'US', 'listeners': 427598},
#  {'timestp': '2020-03-24T00:00:00.000Z', 'code2': 'US', 'listeners': 422772},
#  {'timestp': '2020-03-25T00:00:00.000Z', 'code2': 'US', 'listeners': 419548},
#  {'timestp': '2020-03-26T00:00:00.000Z', 'code2': 'US', 'listeners': 416165},
#  {'timestp': '2020-03-27T00:00:00.000Z', 'code2': 'US', 'listeners': 413550},
#  {'timestp': '2020-03-28T00:00:00.000Z', 'code2': 'US', 'listeners': 409917},
#  {'timestp': '2020-03-29T00:00:00.000Z', 'code2': 'US', 'listeners': 404642},
#  {'timestp': '2020-03-30T00:00:00.000Z', 'code2': 'US', 'listeners': 398183},
#  {'timestp': '2020-03-31T00:00:00.000Z', 'code2': 'US', 'listeners': 392530},
#  {'timestp': '2020-04-01T00:00:00.000Z', 'code2': 'US', 'listeners': 388646},
#  {'timestp': '2020-04-23T00:00:00.000Z', 'code2': 'US', 'listeners': 288813},
#  {'timestp': '2020-04-24T00:00:00.000Z', 'code2': 'US', 'listeners': 286517},
#  {'timestp': '2020-04-25T00:00:00.000Z', 'code2': 'US', 'listeners': 284525},
#  {'timestp': '2020-04-26T00:00:00.000Z', 'code2': 'US', 'listeners': 283311},
#  {'timestp': '2020-04-27T00:00:00.000Z', 'code2': 'US', 'listeners': 282432},
#  {'timestp': '2020-04-28T00:00:00.000Z', 'code2': 'US', 'listeners': 282196},
#  {'timestp': '2020-04-29T00:00:00.000Z', 'code2': 'US', 'listeners': 280635},
#  {'timestp': '2020-04-30T00:00:00.000Z', 'code2': 'US', 'listeners': 279857},
#  {'timestp': '2020-05-01T00:00:00.000Z', 'code2': 'US', 'listeners': 277215},
#  {'timestp': '2020-05-02T00:00:00.000Z', 'code2': 'US', 'listeners': 274826},
#  {'timestp': '2020-05-03T00:00:00.000Z', 'code2': 'US', 'listeners': 279857},
#  {'timestp': '2020-05-04T00:00:00.000Z', 'code2': 'US', 'listeners': 279857},
#  {'timestp': '2020-05-05T00:00:00.000Z', 'code2': 'US', 'listeners': 277847},
#  {'timestp': '2020-05-06T00:00:00.000Z', 'code2': 'US', 'listeners': 274826},
#  {'timestp': '2020-05-07T00:00:00.000Z', 'code2': 'US', 'listeners': 277847},
#  {'timestp': '2020-05-08T00:00:00.000Z', 'code2': 'US', 'listeners': 277847},
#  {'timestp': '2020-05-09T00:00:00.000Z', 'code2': 'US', 'listeners': 275318},
#  {'timestp': '2020-05-10T00:00:00.000Z', 'code2': 'US', 'listeners': 275318},
#  {'timestp': '2020-05-11T00:00:00.000Z', 'code2': 'US', 'listeners': 275318},
#  {'timestp': '2020-05-12T00:00:00.000Z', 'code2': 'US', 'listeners': 279837},
#  {'timestp': '2020-05-13T00:00:00.000Z', 'code2': 'US', 'listeners': 279837},
#  {'timestp': '2020-05-14T00:00:00.000Z', 'code2': 'US', 'listeners': 284690},
#  {'timestp': '2020-05-15T00:00:00.000Z', 'code2': 'US', 'listeners': 289592},
#  {'timestp': '2020-05-16T00:00:00.000Z', 'code2': 'US', 'listeners': 290866},
#  {'timestp': '2020-05-17T00:00:00.000Z', 'code2': 'US', 'listeners': 290866},
#  {'timestp': '2020-05-18T00:00:00.000Z', 'code2': 'US', 'listeners': 290866},
#  {'timestp': '2020-05-19T00:00:00.000Z', 'code2': 'US', 'listeners': 290866},
#  {'timestp': '2020-05-20T00:00:00.000Z', 'code2': 'US', 'listeners': 290866},
#  {'timestp': '2020-05-21T00:00:00.000Z', 'code2': 'US', 'listeners': 296587},
#  {'timestp': '2020-05-22T00:00:00.000Z', 'code2': 'US', 'listeners': 296587},
#  {'timestp': '2020-05-23T00:00:00.000Z', 'code2': 'US', 'listeners': 298573},
#  {'timestp': '2020-05-24T00:00:00.000Z', 'code2': 'US', 'listeners': 296587},
#  {'timestp': '2020-05-25T00:00:00.000Z', 'code2': 'US', 'listeners': 296587},
#  {'timestp': '2020-05-26T00:00:00.000Z', 'code2': 'US', 'listeners': 309097},
#  {'timestp': '2020-05-27T00:00:00.000Z', 'code2': 'US', 'listeners': 309097},
#  {'timestp': '2020-05-28T00:00:00.000Z', 'code2': 'US', 'listeners': 309097},
#  {'timestp': '2020-05-29T00:00:00.000Z', 'code2': 'US', 'listeners': 309097},
#  {'timestp': '2020-05-30T00:00:00.000Z', 'code2': 'US', 'listeners': 309097},
#  {'timestp': '2020-05-31T00:00:00.000Z', 'code2': 'US', 'listeners': 317234},
#  {'timestp': '2020-06-01T00:00:00.000Z', 'code2': 'US', 'listeners': 319303},
#  {'timestp': '2020-06-02T00:00:00.000Z', 'code2': 'US', 'listeners': 319303},
#  {'timestp': '2020-06-03T00:00:00.000Z', 'code2': 'US', 'listeners': 317234},
#  {'timestp': '2020-06-04T00:00:00.000Z', 'code2': 'US', 'listeners': 317234},
#  {'timestp': '2020-06-05T00:00:00.000Z', 'code2': 'US', 'listeners': 322971},
#  {'timestp': '2020-06-06T00:00:00.000Z', 'code2': 'US', 'listeners': 322971},
#  {'timestp': '2020-06-07T00:00:00.000Z', 'code2': 'US', 'listeners': 322971},
#  {'timestp': '2020-06-08T00:00:00.000Z', 'code2': 'US', 'listeners': 322971},
#  {'timestp': '2020-06-09T00:00:00.000Z', 'code2': 'US', 'listeners': 322971},
#  {'timestp': '2020-06-10T00:00:00.000Z', 'code2': 'US', 'listeners': 323321},
#  {'timestp': '2020-06-11T00:00:00.000Z', 'code2': 'US', 'listeners': 322662},
#  {'timestp': '2020-06-12T00:00:00.000Z', 'code2': 'US', 'listeners': 322662},
#  {'timestp': '2020-06-13T00:00:00.000Z', 'code2': 'US', 'listeners': 322662},
#  {'timestp': '2020-06-14T00:00:00.000Z', 'code2': 'US', 'listeners': 322662},
#  {'timestp': '2020-06-15T00:00:00.000Z', 'code2': 'US', 'listeners': 322662},
#  {'timestp': '2020-06-16T00:00:00.000Z', 'code2': 'US', 'listeners': 328988},
#  {'timestp': '2020-06-17T00:00:00.000Z', 'code2': 'US', 'listeners': 328988},
#  {'timestp': '2020-06-18T00:00:00.000Z', 'code2': 'US', 'listeners': 328988},
#  {'timestp': '2020-06-19T00:00:00.000Z', 'code2': 'US', 'listeners': 328988},
#  {'timestp': '2020-06-20T00:00:00.000Z', 'code2': 'US', 'listeners': 328988},
#  {'timestp': '2020-06-21T00:00:00.000Z', 'code2': 'US', 'listeners': 330548},
#  {'timestp': '2020-06-22T00:00:00.000Z', 'code2': 'US', 'listeners': 330548},
#  {'timestp': '2020-06-23T00:00:00.000Z', 'code2': 'US', 'listeners': 331425},
#  {'timestp': '2020-06-24T00:00:00.000Z', 'code2': 'US', 'listeners': 330548},
#  {'timestp': '2020-06-25T00:00:00.000Z', 'code2': 'US', 'listeners': 330548},
#  {'timestp': '2020-06-26T00:00:00.000Z', 'code2': 'US', 'listeners': 321466},
#  {'timestp': '2020-06-27T00:00:00.000Z', 'code2': 'US', 'listeners': 321466},
#  {'timestp': '2020-06-28T00:00:00.000Z', 'code2': 'US', 'listeners': 321466},
#  {'timestp': '2020-06-29T00:00:00.000Z', 'code2': 'US', 'listeners': 321466},
#  {'timestp': '2020-06-30T00:00:00.000Z', 'code2': 'US', 'listeners': 316283},
#  {'timestp': '2020-07-01T00:00:00.000Z', 'code2': 'US', 'listeners': 315190},
#  {'timestp': '2020-07-02T00:00:00.000Z', 'code2': 'US', 'listeners': 315190},
#  {'timestp': '2020-07-03T00:00:00.000Z', 'code2': 'US', 'listeners': 315190},
#  {'timestp': '2020-07-04T00:00:00.000Z', 'code2': 'US', 'listeners': 315190},
#  {'timestp': '2020-07-05T00:00:00.000Z', 'code2': 'US', 'listeners': 315190},
#  {'timestp': '2020-07-06T00:00:00.000Z', 'code2': 'US', 'listeners': 311202},
#  {'timestp': '2020-07-07T00:00:00.000Z', 'code2': 'US', 'listeners': 311202},
#  {'timestp': '2020-07-08T00:00:00.000Z', 'code2': 'US', 'listeners': 311202},
#  {'timestp': '2020-07-09T00:00:00.000Z', 'code2': 'US', 'listeners': 311202},
#  {'timestp': '2020-07-10T00:00:00.000Z', 'code2': 'US', 'listeners': 311202},
#  {'timestp': '2020-07-11T00:00:00.000Z', 'code2': 'US', 'listeners': 301122},
#  {'timestp': '2020-07-12T00:00:00.000Z', 'code2': 'US', 'listeners': 301122},
#  {'timestp': '2020-07-13T00:00:00.000Z', 'code2': 'US', 'listeners': 301122},
#  {'timestp': '2020-07-14T00:00:00.000Z', 'code2': 'US', 'listeners': 301122},
#  {'timestp': '2020-07-15T00:00:00.000Z', 'code2': 'US', 'listeners': 301122},
#  {'timestp': '2020-07-16T00:00:00.000Z', 'code2': 'US', 'listeners': 287334},
#  {'timestp': '2020-07-17T00:00:00.000Z', 'code2': 'US', 'listeners': 287334},
#  {'timestp': '2020-07-18T00:00:00.000Z', 'code2': 'US', 'listeners': 287334},
#  {'timestp': '2020-07-19T00:00:00.000Z', 'code2': 'US', 'listeners': 287334},
#  {'timestp': '2020-07-20T00:00:00.000Z', 'code2': 'US', 'listeners': 287334},
#  {'timestp': '2020-07-21T00:00:00.000Z', 'code2': 'US', 'listeners': 278941},
#  {'timestp': '2020-07-22T00:00:00.000Z', 'code2': 'US', 'listeners': 278941},
#  {'timestp': '2020-07-23T00:00:00.000Z', 'code2': 'US', 'listeners': 278941},
#  {'timestp': '2020-07-24T00:00:00.000Z', 'code2': 'US', 'listeners': 278941},
#  {'timestp': '2020-07-25T00:00:00.000Z', 'code2': 'US', 'listeners': 278941},
#  {'timestp': '2020-07-26T00:00:00.000Z', 'code2': 'US', 'listeners': 278111},
#  {'timestp': '2020-07-27T00:00:00.000Z', 'code2': 'US', 'listeners': 278111},
#  {'timestp': '2020-07-28T00:00:00.000Z', 'code2': 'US', 'listeners': 276712},
#  {'timestp': '2020-07-29T00:00:00.000Z', 'code2': 'US', 'listeners': 278111},
#  {'timestp': '2020-07-30T00:00:00.000Z', 'code2': 'US', 'listeners': 278111},
#  {'timestp': '2020-07-31T00:00:00.000Z', 'code2': 'US', 'listeners': 280279},
#  {'timestp': '2020-08-01T00:00:00.000Z', 'code2': 'US', 'listeners': 279180},
#  {'timestp': '2020-08-02T00:00:00.000Z', 'code2': 'US', 'listeners': 279180},
#  {'timestp': '2020-08-03T00:00:00.000Z', 'code2': 'US', 'listeners': 278464},
#  {'timestp': '2020-08-04T00:00:00.000Z', 'code2': 'US', 'listeners': 278464},
#  {'timestp': '2020-08-05T00:00:00.000Z', 'code2': 'US', 'listeners': 278464},
#  {'timestp': '2020-08-06T00:00:00.000Z', 'code2': 'US', 'listeners': 278464},
#  {'timestp': '2020-08-07T00:00:00.000Z', 'code2': 'US', 'listeners': 278464},
#  {'timestp': '2020-08-08T00:00:00.000Z', 'code2': 'US', 'listeners': 280076},
#  {'timestp': '2020-08-09T00:00:00.000Z', 'code2': 'US', 'listeners': 280076},
#  {'timestp': '2020-08-10T00:00:00.000Z', 'code2': 'US', 'listeners': 280076},
#  {'timestp': '2020-08-11T00:00:00.000Z', 'code2': 'US', 'listeners': 280076},
#  {'timestp': '2020-08-12T00:00:00.000Z', 'code2': 'US', 'listeners': 280076},
#  {'timestp': '2020-08-13T00:00:00.000Z', 'code2': 'US', 'listeners': 282688},
#  {'timestp': '2020-08-14T00:00:00.000Z', 'code2': 'US', 'listeners': 282688},
#  {'timestp': '2020-08-15T00:00:00.000Z', 'code2': 'US', 'listeners': 284644},
#  {'timestp': '2020-08-16T00:00:00.000Z', 'code2': 'US', 'listeners': 285127},
#  {'timestp': '2020-08-17T00:00:00.000Z', 'code2': 'US', 'listeners': 285576},
#  {'timestp': '2020-08-18T00:00:00.000Z', 'code2': 'US', 'listeners': 286318},
#  {'timestp': '2020-08-19T00:00:00.000Z', 'code2': 'US', 'listeners': 287226},
#  {'timestp': '2020-08-20T00:00:00.000Z', 'code2': 'US', 'listeners': 287226},
#  {'timestp': '2020-08-21T00:00:00.000Z', 'code2': 'US', 'listeners': 288296},
#  {'timestp': '2020-08-22T00:00:00.000Z', 'code2': 'US', 'listeners': 288296},
#  {'timestp': '2020-08-23T00:00:00.000Z', 'code2': 'US', 'listeners': 288296},
#  {'timestp': '2020-08-24T00:00:00.000Z', 'code2': 'US', 'listeners': 286942},
#  {'timestp': '2020-08-25T00:00:00.000Z', 'code2': 'US', 'listeners': 286942},
#  {'timestp': '2020-08-26T00:00:00.000Z', 'code2': 'US', 'listeners': 286942},
#  {'timestp': '2020-08-27T00:00:00.000Z', 'code2': 'US', 'listeners': 284491},
#  {'timestp': '2020-08-28T00:00:00.000Z', 'code2': 'US', 'listeners': 283674},
#  {'timestp': '2020-08-29T00:00:00.000Z', 'code2': 'US', 'listeners': 282949},
#  {'timestp': '2020-08-30T00:00:00.000Z', 'code2': 'US', 'listeners': 281978},
#  {'timestp': '2020-08-31T00:00:00.000Z', 'code2': 'US', 'listeners': 281026},
#  {'timestp': '2020-09-01T00:00:00.000Z', 'code2': 'US', 'listeners': 279750},
#  {'timestp': '2020-09-02T00:00:00.000Z', 'code2': 'US', 'listeners': 278824},
#  {'timestp': '2020-09-03T00:00:00.000Z', 'code2': 'US', 'listeners': 277787},
#  {'timestp': '2020-09-04T00:00:00.000Z', 'code2': 'US', 'listeners': 276728},
#  {'timestp': '2020-09-05T00:00:00.000Z', 'code2': 'US', 'listeners': 275923},
#  {'timestp': '2020-09-06T00:00:00.000Z', 'code2': 'US', 'listeners': 275155},
#  {'timestp': '2020-09-07T00:00:00.000Z', 'code2': 'US', 'listeners': 274601},
#  {'timestp': '2020-09-08T00:00:00.000Z', 'code2': 'US', 'listeners': 273686},
#  {'timestp': '2020-09-09T00:00:00.000Z', 'code2': 'US', 'listeners': 273804},
#  {'timestp': '2020-09-10T00:00:00.000Z', 'code2': 'US', 'listeners': 272086},
#  {'timestp': '2020-09-11T00:00:00.000Z', 'code2': 'US', 'listeners': 270302},
#  {'timestp': '2020-09-12T00:00:00.000Z', 'code2': 'US', 'listeners': 268953},
#  {'timestp': '2020-09-13T00:00:00.000Z', 'code2': 'US', 'listeners': 267114},
#  {'timestp': '2020-09-14T00:00:00.000Z', 'code2': 'US', 'listeners': 265865},
#  {'timestp': '2020-09-15T00:00:00.000Z', 'code2': 'US', 'listeners': 264666},
#  {'timestp': '2020-09-16T00:00:00.000Z', 'code2': 'US', 'listeners': 263138},
#  {'timestp': '2020-09-17T00:00:00.000Z', 'code2': 'US', 'listeners': 263138}]

# %% [markdown]
# ### Export the dataframe

# %% [markdown]
# # Postgre
